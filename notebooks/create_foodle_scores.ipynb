# %%
import csv
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

answers_arr = []
with open('/Users/manitk/Documents/GitHub/create-explore/csv/5_letter_dict_foodle.csv', mode='r') as answers_list:
    answers_list = csv.reader(answers_list)
    for i in answers_list:
        answers_arr.append(i[0])

combined_data = ''.join(answers_arr)
letters_list_x = []
letters_list_y = []
letters_dict = {}
letter_counts = Counter(combined_data)

letters_list_x, letters_list_y = zip(*letter_counts.items())

for i in range(len(letters_list_x)):
    letters_dict[letters_list_x[i]] = letters_list_y[i]

sorted_data = sorted(zip(letters_list_x, letters_list_y), key=lambda x: x[1], reverse=True)
sorted_letters_list_x, sorted_letters_list_y = zip(*sorted_data)

numpy_letter_x = np.array(sorted_letters_list_x)
numpy_letter_y = np.array(sorted_letters_list_y)
plt.bar(numpy_letter_x,numpy_letter_y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

alphabet = 'abcdefghijklmnopqrstuvwxyz'

letter_counts = {letter: [0, 0, 0, 0, 0] for letter in alphabet}

for word in answers_arr:
    for i in range(len(word)):
        letter = word[i]
        if letter in alphabet:
            letter_counts[letter][i] += 1

for letter, counts in letter_counts.items():
    temp_prob = []
    for i in counts:
        temp_prob.append(round(i/sum(counts),2))
    letter_counts[letter] = temp_prob
    counts = temp_prob
    print(f'{letter} - {counts}')

data = np.array(list(letter_counts.values()))
fig, ax = plt.subplots()
cax = ax.matshow(data, cmap='YlGnBu')

cbar = fig.colorbar(cax)  # Colorbar

ax.set_xticks(np.arange(5))
ax.set_yticks(np.arange(len(alphabet)))
ax.set_xticklabels(['0', '1', '2', '3', '4'])
ax.set_yticklabels(list(alphabet))

plt.xlabel("Index")
plt.ylabel("Letter")
plt.show()
# Out:
# a - [0.08, 0.35, 0.29, 0.17, 0.12]
# b - [0.66, 0.01, 0.14, 0.13, 0.05]
# c - [0.45, 0.08, 0.13, 0.31, 0.03]
# d - [0.29, 0.01, 0.13, 0.15, 0.42]
# e - [0.02, 0.19, 0.19, 0.28, 0.33]
# f - [0.63, 0.04, 0.09, 0.15, 0.09]
# g - [0.45, 0.03, 0.19, 0.22, 0.11]
# h - [0.16, 0.43, 0.03, 0.11, 0.28]
# i - [0.02, 0.34, 0.4, 0.19, 0.05]
# j - [0.73, 0.07, 0.2, 0.0, 0.0]
# k - [0.21, 0.05, 0.09, 0.24, 0.41]
# l - [0.14, 0.23, 0.19, 0.23, 0.22]
# m - [0.41, 0.15, 0.18, 0.16, 0.09]
# n - [0.06, 0.09, 0.23, 0.35, 0.27]
# o - [0.05, 0.4, 0.27, 0.16, 0.11]
# p - [0.5, 0.13, 0.14, 0.13, 0.1]
# q - [0.45, 0.27, 0.09, 0.0, 0.18]
# r - [0.1, 0.33, 0.22, 0.16, 0.18]
# s - [0.41, 0.01, 0.12, 0.18, 0.28]
# t - [0.21, 0.12, 0.18, 0.27, 0.23]
# u - [0.03, 0.45, 0.36, 0.11, 0.05]
# v - [0.08, 0.08, 0.36, 0.47, 0.0]
# w - [0.44, 0.19, 0.06, 0.23, 0.08]
# x - [0.0, 0.17, 0.67, 0.0, 0.17]
# y - [0.05, 0.03, 0.07, 0.03, 0.81]
# z - [0.05, 0.0, 0.3, 0.5, 0.15]

# %%
score_dict = {}
score = 0

for word in answers_arr:
    score = 0
    for idx, letter in enumerate(word):
        if letter in alphabet:
            score += letters_dict[letter] * data[alphabet.index(letter)][idx]
    score_dict[word] = round(score, 2)

sorted_dict_descending = dict(sorted(score_dict.items(), key=lambda item: item[1], reverse=True))
top_scores = list(sorted_dict_descending.items())

with open("/Users/manitk/Desktop/Wordle/csv/foodle_scores.csv", mode='w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(["Word", "Score"])
        for word, score in top_scores:
            print(f'{word}: {score}')
            csv_writer.writerow([word, score])
# Out:
# sauce: 435.71
# saute: 434.93
# saves: 420.09
# soaks: 415.47
# souse: 409.16
# seals: 402.2
# coats: 401.83
# sorts: 400.64
# saucy: 400.43
# sopes: 397.84
# salty: 395.64
# shake: 394.98
# slice: 393.07
# stale: 389.44
# shire: 387.65
# shape: 387.17
# saver: 386.81
# brine: 379.45
# spare: 379.32
# skate: 378.4
# raise: 377.57
# brass: 377.47
# salad: 376.17
# carve: 375.41
# grate: 374.94
# baste: 371.37
# farce: 368.99
# salsa: 367.56
# slits: 367.43
# spice: 364.15
# corer: 363.44
# fries: 363.34
# stone: 363.24
# sieve: 362.78
# puree: 361.53
# place: 360.96
# shank: 360.78
# plate: 360.18
# sheet: 359.87
# cored: 359.48
# snake: 359.48
# cools: 358.86
# shack: 358.61
# savoy: 358.55
# party: 358.41
# cross: 356.95
# serve: 356.74
# serge: 355.88
# shred: 355.79
# salon: 354.45
# scone: 353.88
# boils: 353.73
# cress: 353.38
# paint: 352.6
# beats: 351.91
# taste: 351.21
# store: 350.59
# grass: 350.26
# moose: 350.06
# caper: 348.85
# chile: 348.78
# shark: 348.13
# goose: 348.06
# waits: 347.65
# based: 347.01
# chars: 346.78
# slash: 345.38
# prune: 345.17
# maize: 344.94
# camel: 343.15
# brand: 343.0
# dance: 343.0
# crepe: 342.23
# loose: 342.23
# score: 341.23
# crazy: 341.11
# three: 340.53
# creme: 340.36
# piece: 340.18
# pride: 339.94
# board: 339.35
# grape: 339.11
# grade: 338.94
# poach: 338.63
# prime: 338.24
# latte: 338.21
# saunf: 337.8
# cooks: 337.75
# press: 337.28
# stand: 337.2
# stirs: 336.14
# dairy: 335.99
# savor: 335.69
# pasty: 335.53
# patty: 335.41
# spike: 335.35
# glace: 334.31
# carol: 333.93
# booze: 333.79
# sabra: 333.75
# paper: 332.75
# swiss: 332.34
# pokes: 332.15
# steel: 331.98
# stack: 331.96
# skins: 330.84
# tater: 330.69
# toast: 329.93
# patis: 329.87
# Dries: 329.32
# tarry: 329.11
# spicy: 328.87
# coral: 328.71
# sheep: 328.07
# boxes: 328.0
# sunny: 327.67
# cooky: 327.33
# stall: 326.96
# solid: 326.91
# horse: 326.82
# snaps: 326.81
# cameo: 326.76
# bagel: 326.18
# fried: 326.1
# large: 325.97
# stove: 325.91
# start: 325.41
# baker: 325.38
# blade: 324.74
# snoek: 324.01
# snack: 323.11
# brain: 323.1
# sleep: 323.01
# table: 322.72
# foams: 322.55
# boned: 322.39
# smoke: 322.22
# tears: 322.05
# cepes: 321.8
# dried: 321.66
# seven: 321.53
# baked: 321.42
# chive: 321.31
# chana: 320.75
# super: 320.61
# tripe: 320.51
# sharp: 320.26
# whale: 319.95
# sweet: 319.54
# cover: 319.2
# sized: 318.38
# morel: 318.35
# spray: 318.24
# scald: 317.98
# baron: 317.78
# crock: 317.24
# candy: 316.96
# small: 316.91
# grant: 316.65
# meaty: 316.28
# roast: 316.03
# short: 316.0
# tasty: 315.93
# grand: 315.79
# smart: 315.36
# palak: 315.34
# penne: 314.76
# grana: 314.35
# cheek: 314.28
# shell: 313.98
# frank: 313.89
# raita: 313.85
# smash: 313.74
# craft: 313.25
# rated: 312.83
# shoot: 312.32
# mange: 312.25
# fancy: 312.16
# brick: 312.11
# water: 311.91
# moves: 311.73
# prick: 311.55
# broad: 311.34
# bliss: 310.41
# ladle: 310.36
# house: 310.3
# heats: 310.25
# green: 309.96
# fatty: 309.93
# chard: 309.54
# drank: 309.45
# leave: 309.35
# snail: 309.06
# glass: 308.85
# greek: 307.88
# bread: 307.77
# harry: 307.61
# honey: 307.55
# notes: 307.42
# dress: 307.36
# pasta: 307.27
# swede: 307.04
# flake: 306.68
# samba: 306.54
# belle: 306.48
# stick: 306.31
# clove: 305.84
# packs: 305.45
# gravy: 305.28
# peels: 304.81
# break: 304.7
# grove: 304.5
# peach: 304.25
# pearl: 304.03
# trail: 303.55
# pulse: 303.44
# range: 303.4
# reese: 303.26
# piano: 303.11
# cacao: 302.91
# wraps: 302.52
# burns: 302.44
# laced: 301.49
# steep: 301.42
# white: 301.21
# tosss: 300.58
# maker: 300.17
# blast: 299.68
# stops: 299.6
# moist: 299.23
# crisp: 299.18
# carom: 299.12
# steak: 298.9
# spear: 298.6
# early: 298.36
# prawn: 298.24
# panir: 298.04
# plank: 297.96
# truss: 297.94
# curly: 297.7
# halve: 297.68
# lager: 297.48
# crust: 297.26
# court: 296.38
# black: 296.35
# carob: 296.02
# stock: 295.9
# grain: 295.89
# smear: 295.88
# style: 295.41
# china: 295.1
# mache: 295.03
# curry: 294.91
# giant: 294.09
# trims: 293.78
# Foils: 293.67
# broth: 293.35
# juice: 293.22
# basil: 292.93
# capon: 292.78
# rises: 292.68
# drain: 292.62
# basin: 292.32
# glaze: 292.23
# pound: 292.07
# label: 292.01
# color: 291.79
# stews: 291.6
# chick: 291.3
# mince: 290.76
# conch: 290.33
# eagle: 290.31
# grind: 290.14
# fatal: 290.08
# peter: 289.96
# feast: 289.67
# layer: 289.63
# maria: 289.54
# sweat: 289.15
# berry: 288.94
# bravo: 288.9
# colby: 288.56
# treat: 288.47
# cream: 288.12
# cider: 287.94
# smith: 287.91
# broil: 287.65
# tawny: 287.44
# sugar: 287.43
# smoky: 286.94
# comal: 286.81
# maida: 286.7
# rotel: 286.5
# fired: 286.34
# chill: 286.3
# clear: 285.86
# crush: 285.76
# drips: 285.33
# natty: 285.21
# speck: 285.0
# groat: 284.99
# swirl: 284.84
# torta: 284.6
# chops: 284.59
# whole: 283.89
# drink: 283.8
# dices: 283.78
# twine: 282.61
# wafer: 282.57
# tarka: 282.53
# rouge: 282.48
# bacon: 282.42
# turns: 282.28
# bowls: 282.21
# dense: 282.07
# sport: 282.02
# rolls: 281.94
# skirt: 281.81
# great: 281.42
# rinse: 281.31
# plain: 281.13
# clean: 280.91
# thaws: 280.52
# molly: 280.37
# binge: 279.95
# grill: 279.9
# chino: 279.77
# farro: 279.64
# penny: 279.48
# trawl: 279.25
# Poach: 279.13
# frost: 278.99
# hotel: 278.9
# smelt: 278.52
# paddy: 278.47
# crown: 278.28
# joint: 278.1
# check: 277.32
# crema: 276.82
# hazel: 276.65
# spoon: 276.49
# Glass: 276.0
# manor: 275.97
# patio: 275.86
# flute: 275.33
# drops: 274.92
# navel: 274.51
# bugle: 274.11
# dulse: 273.52
# snook: 272.89
# panda: 272.6
# bream: 272.58
# lolly: 272.54
# tasso: 272.52
# gator: 272.52
# flank: 272.48
# anise: 272.37
# borax: 271.73
# frito: 271.59
# cocoa: 271.56
# pekoe: 271.51
# pulls: 271.49
# ready: 271.43
# flaky: 271.4
# mixes: 271.23
# belly: 271.2
# dirty: 270.98
# certo: 270.59
# roger: 270.51
# bunny: 270.47
# rotis: 270.42
# brush: 270.22
# wipes: 270.14
# total: 270.01
# mason: 269.69
# terry: 268.78
# scrod: 268.66
# Trays: 268.51
# alive: 268.25
# earth: 267.81
# cloth: 267.48
# mound: 267.42
# kaong: 267.39
# alley: 267.36
# steam: 266.78
# ranch: 266.68
# filet: 266.67
# tongs: 266.49
# chewy: 266.17
# butty: 266.07
# burnt: 266.06
# heavy: 265.45
# panko: 265.25
# leafy: 265.25
# diner: 264.31
# heart: 264.17
# fresh: 263.92
# melts: 263.32
# burst: 263.29
# viand: 263.26
# brown: 262.74
# wheel: 262.49
# heath: 262.37
# blend: 261.96
# liner: 261.75
# fryer: 261.68
# hooch: 261.47
# perch: 261.4
# crimp: 261.3
# folds: 260.87
# world: 260.35
# watch: 260.35
# block: 260.29
# stout: 260.18
# chunk: 259.75
# straw: 259.75
# touch: 259.66
# discs: 259.3
# beefy: 258.66
# round: 258.57
# fills: 258.4
# truck: 258.23
# kraft: 258.02
# globe: 258.0
# juicy: 257.94
# hatch: 257.63
# chuck: 257.58
# mould: 257.56
# latik: 257.08
# skunk: 256.81
# linen: 256.8
# cling: 256.67
# wacky: 256.65
# jolly: 256.47
# poppy: 256.09
# lodge: 256.08
# cheap: 256.02
# thick: 255.6
# basic: 255.51
# ounce: 255.37
# Forks: 255.36
# besan: 255.3
# petal: 255.23
# pipis: 254.82
# cedar: 254.73
# mouth: 253.83
# cajun: 253.63
# chili: 253.14
# tiger: 252.85
# gourd: 252.77
# olive: 252.5
# wilts: 252.41
# rests: 252.12
# proof: 252.07
# agave: 251.7
# tabil: 251.19
# hound: 250.97
# horno: 250.72
# drunk: 250.08
# pista: 249.76
# first: 249.64
# bamba: 249.34
# blood: 249.2
# bobby: 249.09
# lotus: 248.53
# split: 248.44
# flips: 248.36
# third: 248.19
# picks: 247.94
# sumac: 247.1
# lardo: 246.34
# dusts: 246.13
# fiber: 245.84
# trout: 245.82
# holds: 245.25
# field: 244.91
# local: 244.77
# float: 244.75
# scoop: 244.51
# strip: 244.5
# sumaq: 244.04
# coppa: 243.93
# ackee: 243.75
# dilly: 243.54
# major: 243.32
# pinch: 242.67
# niter: 242.58
# pecan: 242.26
# dream: 242.1
# guava: 242.07
# ghost: 241.47
# copha: 241.11
# whips: 240.52
# cuban: 239.69
# fruit: 239.54
# cloud: 239.25
# squid: 239.09
# liver: 239.06
# shoyu: 238.93
# kitty: 238.77
# river: 238.04
# mixer: 237.95
# razor: 237.47
# amuse: 237.45
# bison: 237.39
# quark: 237.22
# pluck: 236.42
# whisk: 236.22
# pinto: 235.76
# fully: 235.59
# grown: 235.53
# wagon: 235.51
# pisco: 235.21
# bisto: 234.99
# halva: 234.14
# mixed: 233.99
# pitia: 233.68
# quail: 233.65
# mango: 233.38
# wheat: 233.34
# sprig: 233.3
# blitz: 233.15
# toddy: 232.92
# mirin: 232.48
# aroma: 232.39
# pimms: 231.72
# pesto: 231.61
# bayou: 230.4
# punch: 230.28
# liken: 229.88
# obese: 229.6
# kasha: 229.49
# droop: 229.19
# whirl: 229.03
# blush: 228.81
# derby: 228.69
# plush: 228.25
# royal: 227.93
# kashk: 227.86
# milky: 227.7
# korma: 227.37
# melds: 227.32
# matzo: 225.87
# sushi: 224.38
# squab: 224.11
# doggy: 223.97
# pilaf: 222.92
# flesh: 222.51
# jelly: 222.09
# opens: 222.07
# quick: 222.05
# knife: 221.76
# jerky: 221.51
# alarm: 221.29
# lauki: 221.03
# crumb: 220.23
# fudge: 219.13
# cumin: 218.94
# twist: 218.6
# zesty: 216.7
# lobby: 216.05
# tucks: 215.95
# wedge: 215.8
# nutty: 215.31
# yield: 215.19
# jeera: 214.79
# thyme: 213.91
# dough: 213.32
# puppy: 212.14
# thigh: 212.01
# melon: 211.71
# tonic: 210.73
# robin: 210.73
# magic: 209.85
# medal: 209.64
# ovens: 209.48
# meson: 209.36
# apple: 209.06
# aioli: 208.52
# dietz: 207.54
# dashi: 206.6
# divan: 206.28
# jewel: 205.75
# mocha: 205.54
# asian: 205.36
# disco: 205.29
# scrub: 204.88
# rajma: 204.75
# quorn: 203.24
# yacht: 203.24
# witch: 202.84
# urban: 202.43
# young: 202.06
# welsh: 201.89
# flour: 201.63
# heeng: 201.52
# vital: 201.43
# syrup: 201.37
# after: 199.8
# okara: 199.75
# below: 198.91
# dutch: 198.91
# nestl: 197.8
# lunch: 197.8
# pepsi: 197.36
# licor: 196.82
# knead: 196.23
# gusto: 195.39
# amino: 195.07
# stuff: 193.7
# recao: 192.98
# lucky: 192.65
# owner: 192.46
# nadru: 190.56
# amber: 188.93
# uncle: 188.51
# acorn: 188.48
# throw: 188.31
# micro: 187.6
# angel: 186.92
# schwa: 186.59
# nashi: 186.32
# ocean: 186.21
# cutup: 184.98
# fizzy: 182.92
# lemon: 182.51
# roqaq: 182.42
# gummy: 182.26
# ivory: 181.85
# devil: 180.76
# pizza: 180.14
# apron: 180.04
# onion: 179.97
# khoya: 177.79
# vodka: 175.62
# other: 173.94
# added: 173.76
# jimmy: 172.75
# avoid: 172.65
# koshi: 171.44
# upper: 171.36
# bundi: 171.16
# fuzzy: 170.53
# yucca: 170.47
# quaff: 168.81
# konbu: 168.3
# kefir: 167.79
# aging: 166.47
# amour: 163.57
# kucai: 161.01
# light: 160.48
# right: 159.46
# myoga: 158.88
# jiffy: 156.81
# kebab: 156.73
# icing: 153.84
# dukka: 153.84
# negro: 151.26
# known: 151.2
# equal: 151.12
# gyoza: 150.82
# achar: 149.94
# kombu: 147.95
# ajvar: 147.06
# kokum: 143.98
# alpha: 142.7
# omega: 142.48
# gumbo: 136.9
# assam: 131.08
# khubz: 125.33
# extra: 124.58
# offal: 119.98
# jumbo: 115.0
# elbow: 105.25
# kudzu: 100.13
# awful: 96.47
# aspic: 87.5

# %%
updated_top_scores = {}

def find_top_unique_words(top_scores, csv_filename):
    unique_word = []
    unique_word_count = 0
    
    for word, score in top_scores:
            unique_word.append((word, score))
            unique_word_count += 1
    
    with open(csv_filename, mode='w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(["Word", "Score"])
        for word, score in unique_word:
            if len(set(word)) == len(word):
                csv_writer.writerow([word, score])
                updated_top_scores[word] = score

top_scores = list(sorted_dict_descending.items())[:]
find_top_unique_words(top_scores,"/Users/manitk/Desktop/Wordle/csv/foodle_unique_scores.csv")

# %%
updated_top_scores_list = list(updated_top_scores.items())
from itertools import combinations

words = [t[0] for t in updated_top_scores_list]
combinations_of_3 = combinations(words, 3)

def has_unique_letters(words):
    all_letters = ''.join(words)
    return len(all_letters) == len(set(all_letters))

unique_letter_combinations = [combo for combo in combinations_of_3 if has_unique_letters(''.join(combo))]
total_scores = [sum(word[1] for word in updated_top_scores_list if word[0] in combo) for combo in unique_letter_combinations]

prob_list = list(zip(unique_letter_combinations, total_scores))
prob_list_sorted = sorted(prob_list, key=lambda x: x[1], reverse=True)

for item in prob_list_sorted:
    print(item)
# Out:
# (('salty', 'boned', 'prick'), 1029.58)
# (('slice', 'party', 'mound'), 1018.9000000000001)
# (('saute', 'grind', 'colby'), 1013.6299999999999)
# (('salty', 'chive', 'pound'), 1009.02)
# (('saute', 'colby', 'drink'), 1007.29)
# (('slice', 'party', 'hound'), 1002.45)
# (('salty', 'brick', 'pound'), 999.8199999999999)
# (('shred', 'paint', 'colby'), 996.95)
# (('brine', 'shack', 'mould'), 995.6199999999999)
# (('salty', 'pride', 'chunk'), 995.3299999999999)
# (('salty', 'prime', 'chunk'), 993.63)
# (('stale', 'brick', 'pound'), 993.6199999999999)
# (('slice', 'gravy', 'pound'), 990.4199999999998)
# (('slice', 'brand', 'mouth'), 989.9)
# (('shank', 'pride', 'colby'), 989.28)
# (('grate', 'boils', 'chunk'), 988.4200000000001)
# (('salty', 'brine', 'dough'), 988.4099999999999)
# (('shank', 'prime', 'colby'), 987.5799999999999)
# (('saute', 'grind', 'block'), 985.3599999999999)
# (('salty', 'prime', 'hound'), 984.85)
# (('salty', 'chive', 'mound'), 984.3700000000001)
# (('salty', 'fried', 'chunk'), 981.49)
# (('waits', 'prune', 'colby'), 981.3799999999999)
# (('salty', 'chive', 'brown'), 979.69)
# (('salty', 'boned', 'crimp'), 979.3299999999999)
# (('chile', 'brand', 'smoky'), 978.72)
# (('paint', 'boxes', 'curly'), 978.3)
# (('shire', 'black', 'pound'), 976.0699999999999)
# (('salty', 'chive', 'round'), 975.52)
# (('shank', 'fried', 'colby'), 975.44)
# (('salty', 'brick', 'mound'), 975.1700000000001)
# (('coats', 'prune', 'milky'), 974.7)
# (('salty', 'prick', 'mound'), 974.6100000000001)
# (('party', 'chile', 'mound'), 974.6100000000001)
# (('saucy', 'grind', 'whole'), 974.4599999999999)
# (('brine', 'savoy', 'pluck'), 974.42)
# (('shake', 'grind', 'colby'), 973.6800000000001)
# (('savoy', 'chile', 'burnt'), 973.3899999999999)
# (('brine', 'pasty', 'mould'), 972.54)
# (('paint', 'smoke', 'curly'), 972.52)
# (('party', 'boils', 'chunk'), 971.8900000000001)
# (('grate', 'spicy', 'mound'), 971.23)
# (('shake', 'curly', 'joint'), 970.7800000000001)
# (('shank', 'tripe', 'colby'), 969.8499999999999)
# (('salty', 'chive', 'gourd'), 969.72)
# (('saucy', 'grind', 'hotel'), 969.4699999999999)
# (('stale', 'brick', 'mound'), 968.97)
# (('brine', 'stack', 'mould'), 968.97)
# (('shred', 'paint', 'block'), 968.6800000000001)
# (('stale', 'prick', 'mound'), 968.4100000000001)
# (('saucy', 'whole', 'drink'), 968.1199999999999)
# (('waits', 'boned', 'curly'), 967.74)
# (('salty', 'chive', 'drunk'), 967.0300000000001)
# (('shape', 'brick', 'mound'), 966.7)
# (('pride', 'saunf', 'colby'), 966.3)
# (('shape', 'grind', 'colby'), 965.8699999999999)
# (('slice', 'gravy', 'mound'), 965.77)
# (('slice', 'party', 'dough'), 964.8)
# (('prime', 'saunf', 'colby'), 964.5999999999999)
# (('prime', 'stand', 'colby'), 964.0)
# (('saucy', 'drink', 'hotel'), 963.13)
# (('shape', 'curly', 'joint'), 962.97)
# (('slice', 'grand', 'mouth'), 962.69)
# (('paint', 'moves', 'curly'), 962.03)
# (('party', 'chive', 'bowls'), 961.9300000000001)
# (('grate', 'solid', 'chunk'), 961.6)
# (('grate', 'spicy', 'mould'), 961.3699999999999)
# (('spice', 'brand', 'mouth'), 960.98)
# (('slice', 'frank', 'mouth'), 960.7900000000001)
# (('salty', 'grove', 'chunk'), 959.89)
# (('coats', 'drink', 'bugle'), 959.74)
# (('shape', 'colby', 'drink'), 959.53)
# (('savoy', 'prune', 'thick'), 959.32)
# (('boils', 'prune', 'watch'), 959.2500000000001)
# (('grate', 'boils', 'punch'), 958.95)
# (('salty', 'brick', 'hound'), 958.72)
# (('savoy', 'pride', 'chunk'), 958.24)
# (('salty', 'prick', 'hound'), 958.1600000000001)
# (('savoy', 'chile', 'drunk'), 957.41)
# (('shire', 'fancy', 'mould'), 957.3699999999999)
# (('skate', 'grind', 'colby'), 957.0999999999999)
# (('shape', 'brick', 'mould'), 956.8399999999999)
# (('sauce', 'broth', 'milky'), 956.76)
# (('savoy', 'prime', 'chunk'), 956.54)
# (('slice', 'drank', 'mouth'), 956.35)
# (('chile', 'smart', 'pound'), 956.21)
# (('brand', 'spicy', 'whole'), 955.76)
# (('boils', 'prune', 'wacky'), 955.5500000000001)
# (('carve', 'pound', 'smith'), 955.3900000000001)
# (('grate', 'spicy', 'hound'), 954.78)
# (('brine', 'pasty', 'cloud'), 954.23)
# (('shank', 'cored', 'blitz'), 953.41)
# (('waits', 'prune', 'block'), 953.1099999999999)
# (('boils', 'grape', 'chunk'), 952.59)
# (('stale', 'brick', 'hound'), 952.52)
# (('salty', 'chive', 'grown'), 952.48)
# (('boils', 'grade', 'chunk'), 952.4200000000001)
# (('chile', 'grant', 'smoky'), 952.3699999999999)
# (('slice', 'gravy', 'mouth'), 952.18)
# (('salty', 'fried', 'punch'), 952.02)
# (('stale', 'prick', 'hound'), 951.96)
# (('saucy', 'boned', 'whirl'), 951.8499999999999)
# (('fries', 'black', 'pound'), 951.76)
# (('chile', 'pasty', 'mound'), 951.73)
# (('salty', 'juice', 'brown'), 951.6)
# (('chile', 'grand', 'smoky'), 951.51)
# (('shire', 'black', 'mound'), 951.4200000000001)
# (('crazy', 'boned', 'smith'), 951.4100000000001)
# (('brine', 'scald', 'mouth'), 951.2600000000001)
# (('brand', 'chive', 'smoky'), 951.25)
# (('shire', 'pound', 'flaky'), 951.12)
# (('brand', 'spicy', 'hotel'), 950.77)
# (('baste', 'prick', 'mound'), 950.3400000000001)
# (('patis', 'boned', 'curly'), 949.96)
# (('slice', 'gravy', 'hound'), 949.3199999999999)
# (('farce', 'pound', 'smith'), 948.97)
# (('salty', 'prime', 'dough'), 947.2)
# (('brand', 'spicy', 'flute'), 947.2)
# (('party', 'chive', 'mound'), 947.1400000000001)
# (('chile', 'pasty', 'brown'), 947.05)
# (('saunf', 'tripe', 'colby'), 946.8699999999999)
# (('shack', 'tripe', 'mound'), 946.54)
# (('party', 'boxes', 'chunk'), 946.1600000000001)
# (('chile', 'gravy', 'pound'), 946.1299999999999)
# (('savoy', 'brick', 'flute'), 945.99)
# (('brand', 'spike', 'cloth'), 945.83)
# (('spike', 'candy', 'broth'), 945.66)
# (('savoy', 'prick', 'flute'), 945.4300000000001)
# (('cored', 'plank', 'smith'), 945.3500000000001)
# (('pride', 'saunf', 'cloth'), 945.22)
# (('slice', 'prawn', 'mouth'), 945.14)
# (('party', 'solid', 'chunk'), 945.07)
# (('savoy', 'fried', 'chunk'), 944.4000000000001)
# (('savoy', 'prick', 'bugle'), 944.21)
# (('crazy', 'spike', 'mound'), 943.8800000000001)
# (('board', 'spicy', 'flute'), 943.55)
# (('prime', 'saunf', 'cloth'), 943.52)
# (('slice', 'pound', 'kraft'), 943.16)
# (('party', 'boxes', 'cling'), 943.0800000000002)
# (('chile', 'pasty', 'round'), 942.8799999999999)
# (('salty', 'grove', 'pinch'), 942.81)
# (('brine', 'packs', 'mould'), 942.46)
# (('saucy', 'drink', 'globe'), 942.23)
# (('salty', 'fired', 'chunk'), 941.73)
# (('saute', 'crown', 'milky'), 940.9100000000001)
# (('cored', 'paint', 'blush'), 940.8900000000001)
# (('spike', 'fancy', 'broth'), 940.86)
# (('prune', 'moist', 'black'), 940.7500000000001)
# (('saucy', 'binge', 'world'), 940.73)
# (('party', 'chive', 'folds'), 940.59)
# (('spike', 'grant', 'colby'), 940.56)
# (('baste', 'prick', 'mould'), 940.48)
# (('salty', 'boned', 'quick'), 940.0799999999999)
# (('plate', 'brick', 'mound'), 939.71)
# (('spike', 'grand', 'colby'), 939.7)
# (('salty', 'mince', 'gourd'), 939.17)
# (('shank', 'tripe', 'mould'), 938.8499999999999)
# (('savoy', 'tripe', 'chunk'), 938.81)
# (('brine', 'packs', 'mouth'), 938.73)
# (('saucy', 'broth', 'field'), 938.6899999999999)
# (('shred', 'giant', 'colby'), 938.44)
# (('brine', 'foams', 'pluck'), 938.42)
# (('spice', 'grant', 'mould'), 938.3599999999999)
# (('shank', 'prime', 'cloud'), 938.27)
# (('saucy', 'grove', 'blitz'), 938.08)
# (('place', 'grind', 'smoky'), 938.04)
# (('pride', 'saunf', 'block'), 938.03)
# (('brand', 'spike', 'touch'), 938.01)
# (('saute', 'world', 'pinch'), 937.9499999999999)
# (('shape', 'grind', 'block'), 937.5999999999999)
# (('shank', 'clove', 'dirty'), 937.5999999999999)
# (('prime', 'candy', 'bowls'), 937.4100000000001)
# (('chile', 'foams', 'burnt'), 937.3899999999999)
# (('party', 'smoke', 'cling'), 937.3000000000002)
# (('party', 'chive', 'mould'), 937.28)
# (('plate', 'grind', 'smoky'), 937.26)
# (('party', 'sized', 'block'), 937.0799999999999)
# (('chile', 'pasty', 'gourd'), 937.0799999999999)
# (('shank', 'morel', 'juicy'), 937.0699999999999)
# (('shack', 'prune', 'blitz'), 936.93)
# (('brine', 'savoy', 'dutch'), 936.91)
# (('savoy', 'prune', 'blitz'), 936.87)
# (('spice', 'gravy', 'mound'), 936.8499999999999)
# (('brand', 'clove', 'smith'), 936.75)
# (('shack', 'tripe', 'mould'), 936.6800000000001)
# (('boils', 'grant', 'chewy'), 936.55)
# (('party', 'sized', 'chunk'), 936.54)
# (('shire', 'pound', 'wacky'), 936.37)
# (('prime', 'saunf', 'block'), 936.3299999999999)
# (('prime', 'stand', 'block'), 935.73)
# (('boils', 'grand', 'chewy'), 935.69)
# (('shank', 'colby', 'fired'), 935.6799999999998)
# (('stone', 'dairy', 'pluck'), 935.65)
# (('spice', 'frank', 'mould'), 935.5999999999999)
# (('brine', 'chops', 'flaky'), 935.4399999999999)
# (('shire', 'tawny', 'block'), 935.3799999999999)
# (('saver', 'pound', 'thick'), 934.48)
# (('spicy', 'mange', 'broth'), 934.47)
# (('chile', 'spray', 'mound'), 934.44)
# (('chile', 'pasty', 'drunk'), 934.39)
# (('crazy', 'white', 'pound'), 934.3899999999999)
# (('pride', 'fancy', 'bowls'), 934.31)
# (('fries', 'candy', 'mouth'), 934.13)
# (('crazy', 'spike', 'mould'), 934.02)
# (('saucy', 'frito', 'blend'), 933.98)
# (('boned', 'stick', 'gravy'), 933.98)
# (('chile', 'prawn', 'smoky'), 933.96)
# (('baste', 'prick', 'hound'), 933.8900000000001)
# (('party', 'juice', 'bowls'), 933.8400000000001)
# (('saunf', 'brick', 'whole'), 933.8000000000001)
# (('boils', 'frank', 'chewy'), 933.79)
# (('spice', 'grand', 'mouth'), 933.7700000000001)
# (('salty', 'pound', 'fiber'), 933.5500000000001)
# (('slice', 'tawny', 'gourd'), 933.28)
# (('saunf', 'prick', 'whole'), 933.24)
# (('brand', 'stick', 'whole'), 933.1999999999999)
# (('stand', 'brick', 'whole'), 933.1999999999999)
# (('brand', 'pokes', 'juicy'), 933.0899999999999)
# (('shire', 'tawny', 'mould'), 932.6499999999999)
# (('stand', 'prick', 'whole'), 932.64)
# (('prime', 'fancy', 'bowls'), 932.6100000000001)
# (('prune', 'solid', 'watch'), 932.4300000000001)
# (('brand', 'spike', 'mouth'), 932.1800000000001)
# (('grate', 'solid', 'punch'), 932.13)
# (('savoy', 'prick', 'blend'), 932.06)
# (('spice', 'frank', 'mouth'), 931.87)
# (('pasty', 'brick', 'whole'), 931.53)
# (('pasty', 'clove', 'grind'), 931.5099999999999)
# (('party', 'mince', 'bowls'), 931.3800000000001)
# (('party', 'boils', 'fudge'), 931.2700000000001)
# (('brand', 'white', 'smoky'), 931.1500000000001)
# (('beats', 'prick', 'mound'), 930.8800000000001)
# (('spicy', 'boned', 'trawl'), 930.51)
# (('cored', 'saunf', 'blitz'), 930.43)
# (('salty', 'grove', 'punch'), 930.42)
# (('crazy', 'spike', 'mouth'), 930.2900000000001)
# (('shred', 'black', 'joint'), 930.2400000000001)
# (('spice', 'broth', 'flank'), 929.98)
# (('party', 'moves', 'chunk'), 929.8900000000001)
# (('saucy', 'filet', 'brown'), 929.84)
# (('boils', 'meaty', 'chunk'), 929.76)
# (('prune', 'black', 'smith'), 929.4300000000001)
# (('spicy', 'grant', 'whole'), 929.41)
# (('boils', 'drank', 'chewy'), 929.3500000000001)
# (('spice', 'broth', 'flaky'), 928.9)
# (('spicy', 'flake', 'broth'), 928.9)
# (('saunf', 'brick', 'hotel'), 928.8100000000001)
# (('chive', 'smart', 'pound'), 928.74)
# (('prune', 'solid', 'wacky'), 928.73)
# (('paint', 'clove', 'brush'), 928.6600000000001)
# (('spicy', 'grand', 'whole'), 928.5500000000001)
# (('shark', 'boned', 'juicy'), 928.46)
# (('shake', 'curly', 'pinto'), 928.44)
# (('grate', 'Foils', 'chunk'), 928.36)
# (('brine', 'pasty', 'dough'), 928.3)
# (('saunf', 'prick', 'hotel'), 928.25)
# (('saucy', 'broth', 'mixed'), 927.77)
# (('saunf', 'white', 'colby'), 927.5699999999999)
# (('crazy', 'spike', 'hound'), 927.4300000000001)
# (('spice', 'drank', 'mouth'), 927.43)
# (('fries', 'black', 'mound'), 927.1100000000001)
# (('spice', 'gravy', 'mould'), 926.99)
# (('boxes', 'prick', 'tawny'), 926.99)
# (('salty', 'brick', 'fudge'), 926.88)
# (('brand', 'stove', 'juicy'), 926.8500000000001)
# (('party', 'moves', 'cling'), 926.8100000000002)
# (('brine', 'smoky', 'watch'), 926.74)
# (('spicy', 'frank', 'whole'), 926.65)
# (('shire', 'flaky', 'mound'), 926.47)
# (('salty', 'prick', 'fudge'), 926.32)
# (('boils', 'rated', 'chunk'), 926.31)
# (('sauce', 'brown', 'milky'), 926.1500000000001)
# (('shape', 'colby', 'drunk'), 925.8100000000001)
# (('grape', 'solid', 'chunk'), 925.77)
# (('waits', 'morel', 'chunk'), 925.75)
# (('brand', 'spicy', 'mouth'), 925.7)
# (('salty', 'pound', 'mixer'), 925.6600000000001)
# (('boils', 'water', 'chunk'), 925.3900000000001)
# (('party', 'house', 'cling'), 925.3800000000001)
# (('saute', 'brown', 'milky'), 925.3700000000001)
# (('pasty', 'clove', 'drink'), 925.1699999999998)
# (('cored', 'saunf', 'milky'), 924.98)
# (('chive', 'grant', 'smoky'), 924.9000000000001)
# (('brine', 'stack', 'dough'), 924.73)
# (('bagel', 'stick', 'pound'), 924.56)
# (('salty', 'mound', 'perch'), 924.4599999999999)
# (('salty', 'juice', 'grown'), 924.39)
# (('large', 'stick', 'pound'), 924.3499999999999)
# (('pasty', 'chive', 'mound'), 924.26)
# (('boils', 'mange', 'truck'), 924.21)
# (('poach', 'style', 'grind'), 924.18)
# (('whale', 'brick', 'pound'), 924.1299999999999)
# (('shack', 'grind', 'flute'), 924.0799999999999)
# (('chive', 'grand', 'smoky'), 924.04)
# (('savoy', 'grind', 'flute'), 924.02)
# (('pokes', 'curly', 'giant'), 923.9399999999998)
# (('sized', 'fancy', 'broth'), 923.89)
# (('dairy', 'boxes', 'chunk'), 923.74)
# (('saucy', 'broth', 'liken'), 923.66)
# (('sized', 'grant', 'colby'), 923.5899999999999)
# (('spicy', 'grand', 'hotel'), 923.5600000000001)
# (('prune', 'foams', 'thick'), 923.32)
# (('spice', 'gravy', 'mouth'), 923.26)
# (('plate', 'brick', 'hound'), 923.26)
# (('shank', 'grove', 'juicy'), 923.22)
# (('brand', 'smoke', 'juicy'), 923.1600000000001)
# (('brand', 'juice', 'smoky'), 923.1600000000001)
# (('shake', 'colby', 'fruit'), 923.0799999999999)
# (('poach', 'sized', 'burnt'), 923.0699999999999)
# (('boils', 'grade', 'punch'), 922.95)
# (('stand', 'prick', 'bugle'), 922.86)
# (('based', 'curly', 'joint'), 922.8100000000001)
# (('crazy', 'pulse', 'joint'), 922.65)
# (('spicy', 'bagel', 'mound'), 922.47)
# (('spicy', 'large', 'mound'), 922.26)
# (('pride', 'foams', 'chunk'), 922.24)
# (('spicy', 'drank', 'whole'), 922.2099999999999)
# (('salty', 'grove', 'quick'), 922.19)
# (('spicy', 'baron', 'flute'), 921.98)
# (('pasty', 'fried', 'block'), 921.9200000000001)
# (('spicy', 'baker', 'mound'), 921.6700000000001)
# (('spicy', 'frank', 'hotel'), 921.66)
# (('dairy', 'stove', 'chunk'), 921.6500000000001)
# (('prune', 'colby', 'smith'), 921.6400000000001)
# (('grade', 'spicy', 'mouth'), 921.64)
# (('chile', 'gravy', 'mound'), 921.48)
# (('foams', 'white', 'curly'), 921.46)
# (('chile', 'foams', 'drunk'), 921.41)
# (('pasty', 'fried', 'chunk'), 921.38)
# (('prime', 'stack', 'hound'), 921.1700000000001)
# (('crazy', 'pound', 'smith'), 921.0900000000001)
# (('savoy', 'fried', 'pluck'), 921.07)
# (('salty', 'brick', 'dough'), 921.0699999999999)
# (('beats', 'prick', 'mould'), 921.02)
# (('fries', 'plank', 'touch'), 920.96)
# (('sized', 'frank', 'colby'), 920.8299999999999)
# (('salty', 'rouge', 'pinch'), 920.79)
# (('shank', 'tripe', 'cloud'), 920.54)
# (('shack', 'boned', 'fruit'), 920.54)
# (('salty', 'prick', 'dough'), 920.51)
# (('meaty', 'brick', 'pound'), 920.46)
# (('spice', 'gravy', 'hound'), 920.4)
# (('slice', 'frank', 'dough'), 920.28)
# (('shake', 'pound', 'blitz'), 920.1999999999999)
# (('salty', 'chive', 'quorn'), 920.19)
# (('chive', 'grant', 'bowls'), 920.1700000000001)
# (('glace', 'trims', 'pound'), 920.1599999999999)
# (('boils', 'meaty', 'drunk'), 920.09)
# (('spicy', 'grand', 'flute'), 919.99)
# (('carve', 'pound', 'wilts'), 919.89)
# (('cored', 'smith', 'flank'), 919.8700000000001)
# (('chile', 'pasty', 'grown'), 919.8399999999999)
# (('boxes', 'curly', 'giant'), 919.79)
# (('slice', 'party', 'konbu'), 919.78)
# (('tripe', 'candy', 'bowls'), 919.6800000000001)
# (('pasty', 'chive', 'brown'), 919.5799999999999)
# (('saunf', 'chive', 'world'), 919.46)
# (('chive', 'grand', 'bowls'), 919.31)
# (('shark', 'colby', 'twine'), 919.3000000000001)
# (('salty', 'grove', 'cumin'), 919.0799999999999)
# (('spicy', 'table', 'mound'), 919.01)
# (('cored', 'smith', 'flaky'), 918.7900000000001)
# (('prick', 'honey', 'blast'), 918.78)
# (('boils', 'gravy', 'chunk'), 918.76)
# (('chile', 'wraps', 'mound'), 918.72)
# (('spike', 'grand', 'cloth'), 918.6200000000001)
# (('saunf', 'tripe', 'block'), 918.5999999999999)
# (('slice', 'mound', 'kraft'), 918.51)
# (('shape', 'dirty', 'block'), 918.44)
# (('baked', 'moist', 'curly'), 918.3500000000001)
# (('whale', 'stick', 'pound'), 918.3299999999999)
# (('poach', 'style', 'drink'), 917.8399999999999)
# (('Dries', 'black', 'pound'), 917.74)
# (('savoy', 'drink', 'flute'), 917.6800000000001)
# (('brine', 'thaws', 'mould'), 917.53)
# (('chive', 'frank', 'bowls'), 917.4100000000001)
# (('shack', 'pound', 'filet'), 917.3500000000001)
# (('spicy', 'drank', 'hotel'), 917.2199999999999)
# (('pasty', 'chive', 'world'), 917.1899999999999)
# (('camel', 'pound', 'skirt'), 917.03)
# (('party', 'boned', 'whisk'), 917.02)
# (('grate', 'bowls', 'chunk'), 916.9)
# (('pride', 'snack', 'mouth'), 916.88)
# (('spicy', 'frank', 'bugle'), 916.87)
# (('savoy', 'drink', 'bugle'), 916.46)
# (('spicy', 'whale', 'mound'), 916.24)
# (('spike', 'craft', 'mound'), 916.02)
# (('crazy', 'boned', 'wilts'), 915.91)
# (('prune', 'moist', 'flaky'), 915.8000000000001)
# (('maize', 'colby', 'turns'), 915.78)
# (('fries', 'pound', 'watch'), 915.76)
# (('shake', 'brown', 'juicy'), 915.6600000000001)
# (('grape', 'colby', 'smith'), 915.5800000000002)
# (('boned', 'gravy', 'smith'), 915.5799999999999)
# (('saucy', 'broth', 'knife'), 915.54)
# (('spicy', 'broad', 'flute'), 915.54)
# (('grade', 'colby', 'smith'), 915.4100000000001)
# (('pasty', 'chive', 'round'), 915.4099999999999)
# (('shape', 'colby', 'fruit'), 915.27)
# (('fries', 'plank', 'mouth'), 915.13)
# (('grate', 'bowls', 'juicy'), 915.0899999999999)
# (('pasty', 'brick', 'mound'), 915.06)
# (('savoy', 'fried', 'punch'), 914.9300000000001)
# (('tripe', 'fancy', 'bowls'), 914.8800000000001)
# (('spicy', 'whale', 'burnt'), 914.8799999999999)
# (('stale', 'brick', 'dough'), 914.8699999999999)
# (('maize', 'burns', 'cloth'), 914.86)
# (('saunf', 'clove', 'dirty'), 914.62)
# (('boned', 'prick', 'thaws'), 914.46)
# (('crazy', 'moist', 'bugle'), 914.45)
# (('spicy', 'broth', 'glaze'), 914.45)
# (('beats', 'prick', 'hound'), 914.4300000000001)
# (('brick', 'heats', 'pound'), 914.4300000000001)
# (('pasty', 'chive', 'mould'), 914.3999999999999)
# (('shank', 'juice', 'world'), 914.35)
# (('shire', 'tawny', 'cloud'), 914.3399999999999)
# (('stale', 'prick', 'dough'), 914.31)
# (('glace', 'pound', 'smith'), 914.29)
# (('prune', 'colby', 'thaws'), 914.25)
# (('smoke', 'curly', 'giant'), 914.01)
# (('boils', 'crazy', 'fudge'), 913.97)
# (('place', 'smoky', 'burnt'), 913.96)
# (('candy', 'pulse', 'broth'), 913.75)
# (('paint', 'smoky', 'bugle'), 913.65)
# (('spicy', 'drank', 'flute'), 913.6499999999999)
# (('pasty', 'morel', 'chunk'), 913.63)
# (('spicy', 'bagel', 'round'), 913.6199999999999)
# (('fries', 'black', 'mouth'), 913.5200000000001)
# (('stand', 'morel', 'juicy'), 913.49)
# (('farce', 'pound', 'wilts'), 913.4699999999999)
# (('shake', 'world', 'juicy'), 913.27)
# (('shank', 'cover', 'blitz'), 913.13)
# (('chive', 'blast', 'pound'), 913.06)
# (('chive', 'drank', 'bowls'), 912.97)
# (('grape', 'stick', 'mound'), 912.8400000000001)
# (('brand', 'chive', 'lotus'), 912.8399999999999)
# (('sized', 'plank', 'court'), 912.7199999999999)
# (('brand', 'moves', 'juicy'), 912.6700000000001)
# (('party', 'juice', 'folds'), 912.5000000000001)
# (('spicy', 'drank', 'bugle'), 912.43)
# (('stove', 'black', 'grind'), 912.4)
# (('based', 'prick', 'mouth'), 912.39)
# (('party', 'chino', 'bugle'), 912.2900000000001)
# (('salty', 'fired', 'punch'), 912.26)
# (('fries', 'pound', 'wacky'), 912.06)
# (('saver', 'pound', 'blitz'), 912.03)
# (('bagel', 'trims', 'pound'), 912.03)
# (('crazy', 'boned', 'split'), 911.94)
# (('waits', 'grove', 'chunk'), 911.9)
# (('crazy', 'boned', 'flips'), 911.86)
# (('party', 'Foils', 'chunk'), 911.83)
# (('spicy', 'baker', 'mould'), 911.81)
# (('saunf', 'morel', 'thick'), 911.7500000000001)
# (('shire', 'mound', 'wacky'), 911.7199999999999)
# (('party', 'chino', 'dulse'), 911.7)
# (('crazy', 'pound', 'smelt'), 911.7)
# (('shred', 'plank', 'juicy'), 911.69)
# (('place', 'smith', 'brown'), 911.61)
# (('shire', 'tawny', 'pluck'), 911.5099999999999)
# (('brick', 'moves', 'tawny'), 911.28)
# (('shape', 'court', 'milky'), 911.25)
# (('plate', 'brick', 'shoyu'), 911.22)
# (('chile', 'tawny', 'drops'), 911.1400000000001)
# (('fries', 'tawny', 'block'), 911.0699999999999)
# (('shack', 'joint', 'bugle'), 910.82)
# (('spice', 'trawl', 'mound'), 910.8199999999999)
# (('spike', 'grand', 'touch'), 910.8000000000002)
# (('snake', 'broth', 'juicy'), 910.77)
# (('moves', 'prick', 'tawny'), 910.72)
# (('fries', 'black', 'hound'), 910.6600000000001)
# (('brine', 'flaky', 'touch'), 910.51)
# (('brand', 'moves', 'thick'), 910.33)
# (('place', 'moist', 'drunk'), 910.2700000000001)
# (('place', 'skirt', 'mound'), 910.19)
# (('shred', 'giant', 'block'), 910.1700000000001)
# (('spicy', 'table', 'round'), 910.1600000000001)
# (('stale', 'brown', 'juicy'), 910.1200000000001)
# (('party', 'mince', 'folds'), 910.0400000000001)
# (('meaty', 'prick', 'bowls'), 910.04)
# (('foams', 'chive', 'burnt'), 909.9200000000001)
# (('brick', 'house', 'tawny'), 909.8500000000001)
# (('savoy', 'white', 'drunk'), 909.84)
# (('saver', 'mound', 'thick'), 909.83)
# (('crazy', 'white', 'mound'), 909.74)
# (('solid', 'grant', 'chewy'), 909.73)
# (('sized', 'plank', 'broth'), 909.6899999999999)
# (('pasty', 'chive', 'gourd'), 909.6099999999999)
# (('pasty', 'grind', 'whole'), 909.56)
# (('spike', 'grant', 'mould'), 909.56)
# (('grand', 'clove', 'smith'), 909.54)
# (('candy', 'grove', 'smith'), 909.3700000000001)
# (('chile', 'pound', 'Trays'), 909.3599999999999)
# (('prick', 'house', 'tawny'), 909.29)
# (('place', 'joint', 'brush'), 909.28)
# (('spicy', 'boned', 'kraft'), 909.28)
# (('spice', 'tawny', 'mould'), 909.1499999999999)
# (('maize', 'curly', 'tongs'), 909.13)
# (('pride', 'colby', 'thaws'), 909.02)
# (('fancy', 'pulse', 'broth'), 908.95)
# (('salty', 'mound', 'fiber'), 908.9)
# (('spicy', 'bagel', 'mouth'), 908.88)
# (('spicy', 'large', 'mouth'), 908.6700000000001)
# (('party', 'boxes', 'quick'), 908.46)
# (('brand', 'moist', 'chewy'), 908.4000000000001)
# (('fries', 'tawny', 'mould'), 908.3399999999999)
# (('foams', 'prick', 'bugle'), 908.21)
# (('spicy', 'water', 'mound'), 908.2)
# (('glace', 'pound', 'skirt'), 908.19)
# (('spike', 'gravy', 'cloth'), 908.11)
# (('saucy', 'brown', 'field'), 908.08)
# (('spicy', 'baker', 'mouth'), 908.08)
# (('boils', 'peach', 'drunk'), 908.0600000000001)
# (('spike', 'gravy', 'mound'), 908.05)
# (('boned', 'curly', 'smith'), 908.0)
# (('patis', 'morel', 'chunk'), 907.97)
# (('salty', 'crimp', 'hound'), 907.9100000000001)
# (('salty', 'crown', 'mixed'), 907.91)
# (('spike', 'fancy', 'world'), 907.86)
# (('shape', 'brown', 'juicy'), 907.8500000000001)
# (('poach', 'burns', 'filet'), 907.74)
# (('frank', 'clove', 'smith'), 907.6400000000001)
# (('dairy', 'moves', 'chunk'), 907.47)
# (('place', 'smith', 'round'), 907.44)
# (('spicy', 'blade', 'mouth'), 907.44)
# (('spicy', 'whale', 'round'), 907.3899999999999)
# (('saunf', 'prick', 'globe'), 907.35)
# (('prime', 'colby', 'thaws'), 907.3199999999999)
# (('poach', 'grind', 'smelt'), 907.29)
# (('short', 'plank', 'juice'), 907.1800000000001)
# (('candy', 'short', 'bugle'), 907.07)
# (('baked', 'curly', 'smith'), 907.03)
# (('solid', 'frank', 'chewy'), 906.97)
# (('chive', 'spray', 'mound'), 906.97)
# (('pasty', 'chive', 'drunk'), 906.92)
# (('shark', 'pound', 'filet'), 906.8700000000001)
# (('stand', 'prick', 'globe'), 906.75)
# (('pokes', 'grant', 'juicy'), 906.74)
# (('saucy', 'globe', 'third'), 906.6200000000001)
# (('saver', 'pound', 'milky'), 906.5799999999999)
# (('savoy', 'prune', 'witch'), 906.5600000000001)
# (('poach', 'trims', 'bugle'), 906.52)
# (('store', 'plank', 'juicy'), 906.49)
# (('chive', 'prawn', 'smoky'), 906.49)
# (('shank', 'bugle', 'frito'), 906.48)
# (('waits', 'boned', 'pluck'), 906.4599999999999)
# (('shake', 'crown', 'blitz'), 906.41)
# (('spike', 'craft', 'mould'), 906.1600000000001)
# (('bagel', 'pound', 'smith'), 906.1600000000001)
# (('shank', 'clove', 'fruit'), 906.1599999999999)
# (('spike', 'candy', 'mouth'), 906.14)
# (('spicy', 'bagel', 'hound'), 906.02)
# (('mange', 'prick', 'bowls'), 906.01)
# (('dairy', 'stock', 'bugle'), 906.0)
# (('saunf', 'brick', 'lodge'), 905.99)
# (('grand', 'stick', 'whole'), 905.99)
# (('stack', 'grind', 'whole'), 905.9899999999999)
# (('whale', 'stock', 'grind'), 905.9899999999999)
# (('large', 'pound', 'smith'), 905.95)
# (('pride', 'fancy', 'mouth'), 905.9300000000001)
# (('pokes', 'grand', 'juicy'), 905.8800000000001)
# (('shank', 'bugle', 'dirty'), 905.87)
# (('spicy', 'grove', 'flank'), 905.85)
# (('spicy', 'large', 'hound'), 905.8100000000001)
# (('whale', 'trims', 'pound'), 905.8)
# (('place', 'trims', 'hound'), 905.71)
# (('grand', 'white', 'colby'), 905.56)
# (('chars', 'pound', 'filet'), 905.52)
# (('shape', 'world', 'juicy'), 905.46)
# (('saunf', 'prick', 'lodge'), 905.4300000000001)
# (('baker', 'pound', 'smith'), 905.3600000000001)
# (('party', 'boxes', 'cumin'), 905.3500000000001)
# (('brand', 'stove', 'pluck'), 905.33)
# (('shred', 'joint', 'flaky'), 905.2900000000001)
# (('brand', 'smoky', 'flute'), 905.27)
# (('shank', 'rotel', 'juicy'), 905.22)
# (('spicy', 'baker', 'hound'), 905.22)
# (('pasty', 'brick', 'mould'), 905.2)
# (('sized', 'prawn', 'colby'), 905.1800000000001)
# (('bagel', 'prick', 'mound'), 905.1500000000001)
# (('spicy', 'bagel', 'drunk'), 905.13)
# (('paint', 'colby', 'fresh'), 905.0800000000002)
# (('spike', 'fancy', 'mould'), 905.0699999999999)
# (('cover', 'plank', 'smith'), 905.0699999999999)
# (('spike', 'grand', 'mouth'), 904.9700000000001)
# (('stone', 'gravy', 'pluck'), 904.9399999999999)
# (('place', 'grind', 'mouth'), 904.93)
# (('brine', 'flaky', 'mouth'), 904.68)
# (('savoy', 'fired', 'chunk'), 904.64)
# (('slice', 'prawn', 'dough'), 904.6299999999999)
# (('fancy', 'grove', 'smith'), 904.5700000000002)
# (('grate', 'smoky', 'pinch'), 904.55)
# (('prune', 'smith', 'flaky'), 904.48)
# (('crazy', 'pound', 'mixes'), 904.4100000000001)
# (('sauce', 'grown', 'blitz'), 904.39)
# (('spicy', 'table', 'gourd'), 904.36)
# (('spice', 'tawny', 'gourd'), 904.3599999999999)
# (('shack', 'bugle', 'frito'), 904.31)
# (('spicy', 'baked', 'mouth'), 904.12)
# (('poach', 'grind', 'flute'), 904.0999999999999)
# (('grate', 'colby', 'whips'), 904.02)
# (('crazy', 'boned', 'whips'), 904.02)
# (('grand', 'white', 'smoky'), 903.94)
# (('salty', 'pride', 'konbu'), 903.8799999999999)
# (('prime', 'candy', 'lotus'), 903.73)
# (('pasty', 'brick', 'lodge'), 903.72)
# (('carve', 'pound', 'whisk'), 903.7)
# (('shack', 'bugle', 'dirty'), 903.7)
# (('frank', 'white', 'colby'), 903.6599999999999)
# (('stick', 'gravy', 'pound'), 903.6599999999999)
# (('stale', 'brick', 'young'), 903.6099999999999)
# (('waits', 'clove', 'drunk'), 903.57)
# (('shack', 'pound', 'tiger'), 903.5300000000001)
# (('shred', 'tawny', 'block'), 903.52)
# (('moves', 'curly', 'giant'), 903.52)
# (('party', 'clove', 'squid'), 903.34)
# (('super', 'giant', 'colby'), 903.26)
# (('grate', 'pound', 'whisk'), 903.23)
# (('pasty', 'whole', 'drink'), 903.22)
# (('drank', 'clove', 'smith'), 903.2)
# (('crazy', 'white', 'folds'), 903.1899999999999)
# (('crazy', 'smith', 'bugle'), 903.13)
# (('spicy', 'grant', 'mould'), 903.0799999999999)
# (('stale', 'prick', 'young'), 903.05)
# (('fried', 'snack', 'mouth'), 903.0400000000001)
# (('brick', 'pulse', 'tawny'), 902.99)
# (('grape', 'stick', 'mould'), 902.98)
# (('spice', 'flaky', 'mound'), 902.97)
# (('spicy', 'flake', 'mound'), 902.97)
# (('solid', 'meaty', 'chunk'), 902.94)
# (('brand', 'chops', 'flute'), 902.9199999999998)
# (('foams', 'curly', 'twine'), 902.86)
# (('party', 'boned', 'quick'), 902.8499999999999)
# (('brand', 'Foils', 'chewy'), 902.8400000000001)
# (('foams', 'tripe', 'chunk'), 902.81)
# (('pride', 'black', 'tongs'), 902.78)
# (('blade', 'prick', 'tongs'), 902.78)
# (('saucy', 'filet', 'grown'), 902.63)
# (('grate', 'colby', 'squid'), 902.59)
# (('boxes', 'grant', 'juicy'), 902.5899999999999)
# (('boils', 'tawny', 'perch'), 902.57)
# (('spicy', 'table', 'hound'), 902.5600000000001)
# (('spare', 'mound', 'thick'), 902.34)
# (('crazy', 'moist', 'blend'), 902.3)
# (('short', 'fancy', 'bugle'), 902.2700000000001)
# (('shank', 'colby', 'tiger'), 902.1899999999999)
# (('salty', 'prime', 'konbu'), 902.1800000000001)
# (('boils', 'prune', 'yacht'), 902.1400000000001)
# (('shank', 'court', 'field'), 902.0699999999999)
# (('slice', 'kraft', 'hound'), 902.06)
# (('brand', 'pulse', 'thick'), 902.0400000000001)
# (('shire', 'mould', 'wacky'), 901.86)
# (('brick', 'halve', 'pound'), 901.8599999999999)
# (('chile', 'smoky', 'burnt'), 901.78)
# (('boxes', 'grand', 'juicy'), 901.73)
# (('stale', 'crimp', 'hound'), 901.71)
# (('table', 'prick', 'mound'), 901.69)
# (('spicy', 'table', 'drunk'), 901.6700000000001)
# (('place', 'smith', 'gourd'), 901.64)
# (('spice', 'flaky', 'burnt'), 901.6099999999999)
# (('spicy', 'flake', 'burnt'), 901.6099999999999)
# (('spicy', 'whale', 'gourd'), 901.5899999999999)
# (('spicy', 'mange', 'world'), 901.47)
# (('spike', 'fancy', 'mouth'), 901.34)
# (('shape', 'brick', 'young'), 901.3399999999999)
# (('saver', 'joint', 'pluck'), 901.33)
# (('salty', 'chunk', 'fiber'), 901.23)
# (('snack', 'tripe', 'mould'), 901.1800000000001)
# (('shred', 'fancy', 'blitz'), 901.1)
# (('prime', 'black', 'tongs'), 901.08)
# (('prune', 'moist', 'wacky'), 901.0500000000001)
# (('shred', 'paint', 'lucky'), 901.0400000000001)
# (('spicy', 'break', 'mound'), 900.99)
# (('poach', 'drink', 'smelt'), 900.95)
# (('brine', 'foams', 'dutch'), 900.91)
# (('prune', 'foams', 'blitz'), 900.87)
# (('spicy', 'frank', 'globe'), 900.76)
# (('brine', 'folds', 'watch'), 900.67)
# (('carve', 'pound', 'blitz'), 900.63)
# (('pride', 'fancy', 'lotus'), 900.63)
# (('shack', 'pride', 'young'), 900.6099999999999)
# (('paint', 'cover', 'blush'), 900.6099999999999)
# (('boned', 'curly', 'thaws'), 900.6099999999999)
# (('chile', 'pound', 'straw'), 900.5999999999999)
# (('boned', 'sharp', 'juicy'), 900.5899999999999)
# (('stone', 'chard', 'milky'), 900.48)
# (('party', 'clove', 'whisk'), 900.47)
# (('dairy', 'boxes', 'pluck'), 900.41)
# (('party', 'bowls', 'chunk'), 900.37)
# (('shark', 'joint', 'bugle'), 900.34)
# (('spicy', 'frank', 'mould'), 900.3199999999999)
# (('boils', 'meaty', 'punch'), 900.29)
# (('spike', 'gravy', 'touch'), 900.29)
# (('spike', 'fancy', 'gourd'), 900.28)
# (('foams', 'curly', 'binge'), 900.2)
# (('bagel', 'short', 'juicy'), 900.1200000000001)
# (('Dries', 'candy', 'mouth'), 900.11)
# (('bagel', 'pound', 'skirt'), 900.06)
# (('saver', 'mould', 'thick'), 899.97)
# (('bagel', 'stick', 'mound'), 899.9100000000001)
# (('crazy', 'white', 'mould'), 899.8799999999999)
# (('crazy', 'pound', 'filet'), 899.8500000000001)
# (('boxes', 'frank', 'juicy'), 899.8299999999999)
# (('grate', 'bowls', 'pinch'), 899.8199999999999)
# (('table', 'grind', 'smoky'), 899.8)
# (('pasty', 'grove', 'chunk'), 899.78)
# (('sized', 'frank', 'cloth'), 899.75)
# (('salty', 'mince', 'dough'), 899.72)
# (('grate', 'colby', 'whisk'), 899.72)
# (('crazy', 'boned', 'whisk'), 899.72)
# (('large', 'stick', 'mound'), 899.7)
# (('stand', 'grove', 'juicy'), 899.6400000000001)
# (('stove', 'grand', 'juicy'), 899.6400000000001)
# (('brick', 'style', 'pound'), 899.5899999999999)
# (('spike', 'craft', 'hound'), 899.57)
# (('skate', 'pound', 'whirl'), 899.5)
# (('whale', 'brick', 'mound'), 899.48)
# (('slice', 'party', 'kombu'), 899.4300000000001)
# (('boxes', 'grand', 'thick'), 899.39)
# (('pride', 'blast', 'chunk'), 899.37)
# (('saunf', 'white', 'block'), 899.3)
# (('party', 'binge', 'folds'), 899.23)
# (('brine', 'thaws', 'cloud'), 899.22)
# (('drank', 'white', 'colby'), 899.22)
# (('prune', 'Foils', 'watch'), 899.19)
# (('skate', 'brown', 'juicy'), 899.0799999999999)
# (('Dries', 'fancy', 'mould'), 899.04)
# (('chars', 'joint', 'bugle'), 898.99)
# (('place', 'smith', 'drunk'), 898.95)
# (('sauce', 'grown', 'milky'), 898.94)
# (('prime', 'fancy', 'lotus'), 898.9300000000001)
# (('whale', 'prick', 'mound'), 898.9200000000001)
# (('shack', 'prime', 'young'), 898.9100000000001)
# (('shack', 'binge', 'world'), 898.91)
# (('spicy', 'whale', 'drunk'), 898.9)
# (('grate', 'Foils', 'punch'), 898.89)
# (('chile', 'pound', 'kraft'), 898.8699999999999)
# (('boils', 'mache', 'drunk'), 898.84)
# (('spicy', 'frank', 'lodge'), 898.8399999999999)
# (('chive', 'grant', 'folds'), 898.83)
# (('shack', 'twine', 'mould'), 898.78)
# (('blade', 'short', 'juicy'), 898.6800000000001)
# (('pasty', 'brick', 'hound'), 898.61)
# (('shape', 'crown', 'blitz'), 898.6)
# (('place', 'drink', 'mouth'), 898.59)
# (('solid', 'water', 'chunk'), 898.57)
# (('gravy', 'white', 'pound'), 898.56)
# (('whale', 'brick', 'tongs'), 898.55)
# (('spicy', 'grand', 'mouth'), 898.4900000000001)
# (('shank', 'grove', 'blitz'), 898.43)
# (('board', 'pulse', 'thick'), 898.39)
# (('spicy', 'water', 'mould'), 898.3399999999999)
# (('dairy', 'stove', 'pluck'), 898.32)
# (('spice', 'flaky', 'brown'), 898.29)
# (('spicy', 'flake', 'brown'), 898.29)
# (('chive', 'plank', 'frost'), 898.26)
# (('brine', 'packs', 'dough'), 898.22)
# (('moves', 'black', 'grind'), 898.22)
# (('spike', 'gravy', 'mould'), 898.19)
# (('saute', 'grown', 'milky'), 898.1600000000001)
# (('fried', 'tawny', 'chops'), 898.1299999999999)
# (('grape', 'moist', 'chunk'), 898.09)
# (('whale', 'prick', 'tongs'), 897.99)
# (('baste', 'grind', 'pluck'), 897.93)
# (('grade', 'moist', 'chunk'), 897.9200000000001)
# (('saunf', 'grove', 'thick'), 897.9)
# (('poach', 'drink', 'flute'), 897.76)
# (('stove', 'frank', 'juicy'), 897.74)
# (('honey', 'black', 'trims'), 897.6800000000001)
# (('prime', 'blast', 'chunk'), 897.6700000000001)
# (('table', 'grind', 'chops'), 897.45)
# (('shank', 'flute', 'crimp'), 897.4099999999999)
# (('solid', 'mange', 'truck'), 897.3900000000001)
# (('maize', 'short', 'pluck'), 897.36)
# (('brine', 'watch', 'mould'), 897.3599999999999)
# (('saver', 'cling', 'mouth'), 897.3100000000001)
# (('farce', 'pound', 'whisk'), 897.28)
# (('solid', 'peach', 'burnt'), 897.22)
# (('baked', 'curly', 'joint'), 897.22)
# (('saucy', 'brown', 'mixed'), 897.1600000000001)
# (('chive', 'spray', 'mould'), 897.1099999999999)
# (('whale', 'grind', 'smoky'), 897.03)
# (('brine', 'folds', 'wacky'), 896.9699999999999)
# (('boxes', 'plank', 'dirty'), 896.94)
# (('party', 'juice', 'holds'), 896.8800000000001)
# (('chars', 'boned', 'milky'), 896.8699999999999)
# (('boils', 'rated', 'punch'), 896.8399999999999)
# (('smoke', 'grant', 'juicy'), 896.81)
# (('grant', 'juice', 'smoky'), 896.81)
# (('house', 'black', 'grind'), 896.7900000000001)
# (('stick', 'early', 'pound'), 896.74)
# (('savoy', 'binge', 'truck'), 896.73)
# (('spicy', 'broth', 'navel'), 896.73)
# (('skate', 'world', 'juicy'), 896.69)
# (('shack', 'flute', 'brown'), 896.6800000000001)
# (('prime', 'candy', 'ghost'), 896.6700000000001)
# (('brand', 'stove', 'milky'), 896.6100000000001)
# (('brand', 'smoky', 'filet'), 896.6100000000001)
# (('spicy', 'frank', 'mouth'), 896.59)
# (('poach', 'drink', 'bugle'), 896.5400000000001)
# (('shack', 'pound', 'fiber'), 896.5200000000001)
# (('crazy', 'pound', 'melts'), 896.5)
# (('brick', 'glaze', 'pound'), 896.4100000000001)
# (('grape', 'stick', 'hound'), 896.3900000000001)
# (('brine', 'thaws', 'pluck'), 896.39)
# (('paint', 'crush', 'globe'), 896.36)
# (('skate', 'broil', 'punch'), 896.3299999999999)
# (('spicy', 'drank', 'globe'), 896.3199999999999)
# (('savoy', 'pride', 'lunch'), 896.29)
# (('waits', 'morel', 'punch'), 896.28)
# (('shack', 'grove', 'blitz'), 896.26)
# (('baste', 'prick', 'dough'), 896.24)
# (('snake', 'colby', 'third'), 896.23)
# (('boned', 'spray', 'thick'), 896.23)
# (('shank', 'bugle', 'crimp'), 896.19)
# (('savoy', 'white', 'pluck'), 896.18)
# (('shack', 'binge', 'mould'), 896.1199999999999)
# (('place', 'smoky', 'third'), 896.0899999999999)
# (('foams', 'prick', 'blend'), 896.06)
# (('stick', 'halve', 'pound'), 896.06)
# (('boils', 'wafer', 'chunk'), 896.05)
# (('smoke', 'grand', 'juicy'), 895.95)
# (('grand', 'juice', 'smoky'), 895.95)
# (('stone', 'flaky', 'crimp'), 895.94)
# (('party', 'binge', 'mould'), 895.9200000000001)
# (('boils', 'water', 'punch'), 895.9200000000001)
# (('dairy', 'chops', 'flute'), 895.9099999999999)
# (('stick', 'lager', 'pound'), 895.8599999999999)
# (('savoy', 'prime', 'dutch'), 895.6999999999999)
# (('boned', 'smart', 'juicy'), 895.69)
# (('prime', 'fancy', 'holds'), 895.6500000000001)
# (('maize', 'chops', 'burnt'), 895.5899999999999)
# (('grate', 'folds', 'chunk'), 895.56)
# (('shake', 'mound', 'blitz'), 895.5500000000001)
# (('chive', 'grant', 'mould'), 895.52)
# (('carve', 'smoky', 'blitz'), 895.5)
# (('prune', 'Foils', 'wacky'), 895.49)
# (('stick', 'gravy', 'whole'), 895.4799999999999)
# (('boxes', 'drank', 'juicy'), 895.3900000000001)
# (('paint', 'bugle', 'scrod'), 895.3700000000001)
# (('baked', 'short', 'juicy'), 895.3600000000001)
# (('sized', 'grant', 'block'), 895.3199999999999)
# (('Dries', 'fancy', 'mouth'), 895.3100000000001)
# (('cored', 'tawny', 'flips'), 895.2800000000001)
# (('carve', 'mound', 'wilts'), 895.24)
# (('carve', 'pound', 'milky'), 895.1800000000001)
# (('savoy', 'flute', 'crimp'), 895.1800000000001)
# (('fried', 'colby', 'thaws'), 895.1800000000001)
# (('chive', 'burns', 'flaky'), 895.15)
# (('super', 'black', 'joint'), 895.0600000000001)
# (('boils', 'great', 'chunk'), 894.9000000000001)
# (('grate', 'pound', 'milky'), 894.71)
# (('spicy', 'broth', 'flank'), 894.7)
# (('dairy', 'chops', 'bugle'), 894.6899999999999)
# (('brine', 'foams', 'lucky'), 894.65)
# (('candy', 'trims', 'whole'), 894.63)
# (('savoy', 'prime', 'lunch'), 894.5899999999999)
# (('bagel', 'chops', 'drink'), 894.5699999999999)
# (('poach', 'skirt', 'bugle'), 894.5500000000001)
# (('salty', 'chino', 'fudge'), 894.54)
# (('board', 'style', 'chunk'), 894.51)
# (('spike', 'gravy', 'mouth'), 894.46)
# (('paint', 'crush', 'lodge'), 894.44)
# (('party', 'mince', 'holds'), 894.4200000000001)
# (('spice', 'trawl', 'hound'), 894.37)
# (('poach', 'trims', 'blend'), 894.3699999999999)
# (('dairy', 'boxes', 'punch'), 894.27)
# (('brand', 'chops', 'filet'), 894.26)
# (('farce', 'pound', 'blitz'), 894.2099999999999)
# (('patis', 'grove', 'chunk'), 894.12)
# (('spice', 'flaky', 'round'), 894.1199999999999)
# (('spicy', 'flake', 'round'), 894.1199999999999)
# (('baked', 'short', 'cling'), 894.0900000000001)
# (('shack', 'twine', 'gourd'), 893.99)
# (('spicy', 'halve', 'mound'), 893.97)
# (('savoy', 'bugle', 'crimp'), 893.96)
# (('foams', 'chive', 'drunk'), 893.94)
# (('brick', 'pound', 'feast'), 893.8500000000001)
# (('slice', 'tawny', 'dough'), 893.8299999999999)
# (('whale', 'pound', 'skirt'), 893.8299999999999)
# (('spicy', 'lager', 'mound'), 893.77)
# (('grate', 'folds', 'juicy'), 893.75)
# (('place', 'skirt', 'hound'), 893.74)
# (('whale', 'stick', 'mound'), 893.6800000000001)
# (('brine', 'mould', 'wacky'), 893.66)
# (('pride', 'fancy', 'ghost'), 893.57)
# (('pasty', 'drink', 'bugle'), 893.4399999999999)
# (('place', 'broth', 'squid'), 893.4)
# (('prune', 'smith', 'block'), 893.3700000000001)
# (('salty', 'chunk', 'mixer'), 893.3399999999999)
# (('brick', 'pound', 'sweat'), 893.33)
# (('crazy', 'joint', 'bugle'), 893.32)
# (('shake', 'joint', 'crumb'), 893.3100000000001)
# (('stove', 'drank', 'juicy'), 893.3)
# (('meaty', 'pound', 'swirl'), 893.1899999999998)
# (('shape', 'crown', 'milky'), 893.1500000000001)
# (('pokes', 'curly', 'viand'), 893.1099999999999)
# (('spicy', 'bravo', 'flute'), 893.0999999999999)
# (('Dries', 'black', 'mound'), 893.0900000000001)
# (('salty', 'crown', 'fudge'), 893.05)
# (('boxes', 'gravy', 'chunk'), 893.03)
# (('boned', 'crisp', 'flaky'), 892.9699999999999)
# (('Dries', 'pound', 'flaky'), 892.79)
# (('bagel', 'crisp', 'mound'), 892.78)
# (('chive', 'frank', 'mould'), 892.76)
# (('crazy', 'joint', 'dulse'), 892.73)
# (('shack', 'mound', 'filet'), 892.7)
# (('saunf', 'whole', 'dirty'), 892.6700000000001)
# (('chive', 'pound', 'trawl'), 892.63)
# (('spicy', 'halve', 'burnt'), 892.6099999999999)
# (('grape', 'Foils', 'chunk'), 892.53)
# (('flake', 'trims', 'pound'), 892.53)
# (('pokes', 'fancy', 'third'), 892.5)
# (('spare', 'mould', 'thick'), 892.48)
# (('baste', 'pound', 'whirl'), 892.47)
# (('shank', 'curly', 'mixed'), 892.47)
# (('prune', 'smoky', 'watch'), 892.46)
# (('salty', 'hound', 'fiber'), 892.45)
# (('salty', 'brown', 'mixed'), 892.37)
# (('bagel', 'smith', 'crown'), 892.37)
# (('pasty', 'chive', 'grown'), 892.3699999999999)
# (('grade', 'Foils', 'chunk'), 892.36)
# (('brine', 'flaky', 'ghost'), 892.3199999999999)
# (('scone', 'gravy', 'blitz'), 892.31)
# (('grand', 'colby', 'smith'), 892.26)
# (('party', 'moves', 'quick'), 892.19)
# (('dairy', 'stove', 'punch'), 892.1800000000001)
# (('shack', 'frito', 'blend'), 892.1600000000001)
# (('grate', 'smoky', 'punch'), 892.16)
# (('spicy', 'drank', 'mouth'), 892.15)
# (('poach', 'grind', 'melts'), 892.0899999999999)
# (('grant', 'juice', 'bowls'), 892.0799999999999)
# (('candy', 'pulse', 'frito'), 891.99)
# (('clove', 'prawn', 'smith'), 891.99)
# (('solid', 'gravy', 'chunk'), 891.94)
# (('sized', 'frank', 'touch'), 891.9300000000001)
# (('prime', 'fancy', 'ghost'), 891.8700000000001)
# (('saunf', 'clove', 'third'), 891.8299999999999)
# (('boils', 'grape', 'dutch'), 891.75)
# (('crazy', 'boned', 'plush'), 891.75)
# (('spicy', 'water', 'hound'), 891.75)
# (('saunf', 'broil', 'chewy'), 891.6200000000001)
# (('waits', 'honey', 'pluck'), 891.62)
# (('salon', 'prime', 'dutch'), 891.6)
# (('spike', 'gravy', 'hound'), 891.6)
# (('chile', 'tawny', 'Forks'), 891.58)
# (('bagel', 'prick', 'mouth'), 891.5600000000001)
# (('pasty', 'juice', 'brown'), 891.49)
# (('baste', 'world', 'chunk'), 891.47)
# (('camel', 'joint', 'brush'), 891.47)
# (('pasty', 'clove', 'drunk'), 891.4499999999999)
# (('sharp', 'colby', 'twine'), 891.43)
# (('spice', 'frank', 'dough'), 891.3599999999999)
# (('boxes', 'trail', 'chunk'), 891.3)
# (('carve', 'mound', 'split'), 891.27)
# (('spike', 'grant', 'cloud'), 891.25)
# (('chive', 'wraps', 'mound'), 891.25)
# (('grand', 'juice', 'bowls'), 891.22)
# (('carve', 'mound', 'flips'), 891.19)
# (('shank', 'court', 'mixed'), 891.15)
# (('brand', 'moves', 'pluck'), 891.15)
# (('baste', 'pound', 'milky'), 891.1400000000001)
# (('sized', 'gravy', 'cloth'), 891.14)
# (('spicy', 'break', 'mould'), 891.1299999999999)
# (('fries', 'mound', 'watch'), 891.11)
# (('table', 'chops', 'drink'), 891.1099999999999)
# (('chard', 'pulse', 'joint'), 891.08)
# (('salty', 'gourd', 'pinch'), 891.0799999999999)
# (('bagel', 'stick', 'round'), 891.06)
# (('boned', 'crust', 'flaky'), 891.05)
# (('stand', 'broil', 'chewy'), 891.02)
# (('meaty', 'grind', 'chops'), 891.01)
# (('crazy', 'smith', 'blend'), 890.98)
# (('brine', 'cloth', 'sumaq'), 890.97)
# (('brand', 'stove', 'quick'), 890.96)
# (('blade', 'smith', 'crown'), 890.9300000000001)
# (('grate', 'mound', 'flips'), 890.72)
# (('skate', 'crimp', 'hound'), 890.6700000000001)
# (('stick', 'glaze', 'pound'), 890.6099999999999)
# (('stone', 'gravy', 'quick'), 890.5699999999999)
# (('shred', 'joint', 'wacky'), 890.5400000000001)
# (('spicy', 'bread', 'mouth'), 890.47)
# (('spice', 'flank', 'mouth'), 890.46)
# (('burns', 'white', 'comal'), 890.46)
# (('grove', 'plank', 'smith'), 890.3700000000001)
# (('frank', 'colby', 'smith'), 890.3600000000001)
# (('candy', 'moist', 'bugle'), 890.3000000000001)
# (('grate', 'mound', 'picks'), 890.3)
# (('tripe', 'fancy', 'mould'), 890.23)
# (('saunf', 'cover', 'blitz'), 890.15)
# (('pride', 'black', 'mouth'), 890.12)
# (('blade', 'prick', 'mouth'), 890.12)
# (('bagel', 'crush', 'joint'), 890.0400000000001)
# (('salty', 'fried', 'konbu'), 890.04)
# (('fries', 'tawny', 'cloud'), 890.03)
# (('place', 'grind', 'shoyu'), 890.03)
# (('party', 'mixes', 'block'), 889.9300000000001)
# (('brine', 'wacky', 'mouth'), 889.93)
# (('fancy', 'trims', 'whole'), 889.83)
# (('spicy', 'range', 'mould'), 889.8299999999999)
# (('spare', 'cling', 'mouth'), 889.82)
# (('savoy', 'brick', 'fudge'), 889.7900000000001)
# (('crazy', 'spike', 'dough'), 889.78)
# (('brick', 'heats', 'mound'), 889.78)
# (('shank', 'dirty', 'globe'), 889.76)
# (('shack', 'pound', 'liver'), 889.74)
# (('prune', 'smith', 'wacky'), 889.73)
# (('baste', 'world', 'juicy'), 889.6600000000001)
# (('white', 'black', 'pound'), 889.6299999999999)
# (('spice', 'mound', 'kraft'), 889.5899999999999)
# (('boxes', 'grind', 'flaky'), 889.54)
# (('saucy', 'grind', 'below'), 889.4799999999999)
# (('pasty', 'chino', 'bugle'), 889.41)
# (('spice', 'flank', 'gourd'), 889.4)
# (('party', 'mixes', 'chunk'), 889.3900000000001)
# (('salty', 'chunk', 'mixed'), 889.38)
# (('spice', 'flaky', 'mouth'), 889.38)
# (('spicy', 'flake', 'mouth'), 889.38)
# (('brand', 'clove', 'whips'), 889.3599999999999)
# (('table', 'crisp', 'mound'), 889.3200000000002)
# (('frank', 'juice', 'bowls'), 889.3199999999999)
# (('boils', 'gravy', 'punch'), 889.29)
# (('spicy', 'halve', 'brown'), 889.29)
# (('meaty', 'brick', 'folds'), 889.26)
# (('plate', 'grind', 'shoyu'), 889.25)
# (('savoy', 'prick', 'fudge'), 889.23)
# (('honey', 'black', 'drips'), 889.23)
# (('prick', 'heats', 'mound'), 889.22)
# (('spicy', 'blade', 'grown'), 889.14)
# (('pasty', 'juice', 'world'), 889.1)
# (('farce', 'smoky', 'blitz'), 889.08)
# (('chile', 'tawny', 'gourd'), 888.99)
# (('boxes', 'curly', 'viand'), 888.96)
# (('heats', 'grind', 'colby'), 888.95)
# (('fried', 'black', 'tongs'), 888.94)
# (('prime', 'blast', 'hound'), 888.8900000000001)
# (('boxes', 'gravy', 'thick'), 888.88)
# (('shank', 'colby', 'fruit'), 888.8799999999999)
# (('farce', 'mound', 'wilts'), 888.82)
# (('farce', 'pound', 'milky'), 888.76)
# (('grove', 'black', 'smith'), 888.76)
# (('bagel', 'prick', 'hound'), 888.7)
# (('meaty', 'prick', 'folds'), 888.6999999999999)
# (('pokes', 'candy', 'fruit'), 888.6499999999999)
# (('shack', 'pound', 'mixer'), 888.6300000000001)
# (('meaty', 'grind', 'bowls'), 888.6299999999999)
# (('blade', 'crush', 'joint'), 888.6)
# (('waits', 'grove', 'pluck'), 888.5699999999999)
# (('spicy', 'glaze', 'mound'), 888.52)
# (('dairy', 'smoke', 'punch'), 888.49)
# (('gravy', 'pulse', 'chino'), 888.49)
# (('spicy', 'boned', 'quark'), 888.48)
# (('shake', 'juicy', 'grown'), 888.45)
# (('chive', 'blast', 'mound'), 888.4100000000001)
# (('slice', 'party', 'gumbo'), 888.38)
# (('boxes', 'fancy', 'third'), 888.3500000000001)
# (('spice', 'flaky', 'gourd'), 888.3199999999999)
# (('spicy', 'flake', 'gourd'), 888.3199999999999)
# (('shark', 'twine', 'mould'), 888.3)
# (('fancy', 'white', 'drops'), 888.29)
# (('savoy', 'bugle', 'thick'), 888.2600000000001)
# (('spike', 'comal', 'burnt'), 888.22)
# (('shack', 'filet', 'brown'), 888.02)
# (('stick', 'pound', 'layer'), 888.01)
# (('solid', 'mache', 'burnt'), 888.0)
# (('pasty', 'crown', 'bugle'), 887.92)
# (('shred', 'black', 'pinto'), 887.9000000000001)
# (('shape', 'mound', 'blitz'), 887.74)
# (('pride', 'tawny', 'block'), 887.6700000000001)
# (('baked', 'smith', 'crown'), 887.61)
# (('shack', 'dirty', 'globe'), 887.59)
# (('snake', 'colby', 'fruit'), 887.5799999999999)
# (('boned', 'trims', 'flaky'), 887.5699999999999)
# (('chile', 'pasty', 'quorn'), 887.55)
# (('maize', 'turns', 'block'), 887.51)
# (('chive', 'smoky', 'trawl'), 887.5)
# (('stove', 'grind', 'flaky'), 887.4499999999999)
# (('place', 'smoky', 'fruit'), 887.4399999999999)
# (('grate', 'bowls', 'punch'), 887.43)
# (('fries', 'mound', 'wacky'), 887.41)
# (('spicy', 'break', 'mouth'), 887.4)
# (('saver', 'mound', 'blitz'), 887.38)
# (('candy', 'smith', 'rouge'), 887.35)
# (('grape', 'smith', 'block'), 887.31)
# (('glace', 'smoky', 'burnt'), 887.31)
# (('shank', 'colby', 'mixer'), 887.29)
# (('sized', 'court', 'flank'), 887.24)
# (('grate', 'chops', 'milky'), 887.23)
# (('pride', 'smoky', 'watch'), 887.23)
# (('frank', 'moist', 'bugle'), 887.23)
# (('fries', 'tawny', 'pluck'), 887.1999999999999)
# (('chile', 'brand', 'gusto'), 887.17)
# (('spicy', 'glaze', 'burnt'), 887.1600000000001)
# (('grade', 'smith', 'block'), 887.1400000000001)
# (('spicy', 'table', 'grown'), 887.12)
# (('saver', 'mould', 'pinch'), 887.04)
# (('crazy', 'smith', 'globe'), 887.02)
# (('shape', 'block', 'fruit'), 887.0)
# (('chars', 'twine', 'mould'), 886.95)
# (('pasty', 'boned', 'whirl'), 886.9499999999999)
# (('Dries', 'plank', 'touch'), 886.94)
# (('maize', 'bowls', 'chunk'), 886.9)
# (('spray', 'white', 'mound'), 886.8700000000001)
# (('gravy', 'pulse', 'joint'), 886.82)
# (('shack', 'fried', 'young'), 886.77)
# (('maize', 'sport', 'chunk'), 886.71)
# (('dance', 'short', 'milky'), 886.7)
# (('shake', 'round', 'blitz'), 886.6999999999999)
# (('flake', 'pound', 'smith'), 886.6600000000001)
# (('pasty', 'mince', 'world'), 886.64)
# (('prime', 'tawny', 'folds'), 886.5500000000001)
# (('whale', 'crisp', 'mound'), 886.55)
# (('spice', 'flaky', 'hound'), 886.52)
# (('spicy', 'flake', 'hound'), 886.52)
# (('grant', 'moves', 'juicy'), 886.3199999999999)
# (('shred', 'giant', 'pluck'), 886.3)
# (('waits', 'colby', 'drunk'), 886.2900000000001)
# (('place', 'drink', 'ghost'), 886.23)
# (('shred', 'flank', 'juicy'), 886.21)
# (('short', 'mange', 'juicy'), 886.19)
# (('sized', 'court', 'flaky'), 886.16)
# (('mange', 'colby', 'drips'), 886.1399999999999)
# (('spicy', 'range', 'mouth'), 886.1)
# (('sized', 'frank', 'mouth'), 886.1)
# (('shire', 'black', 'young'), 886.06)
# (('salty', 'cover', 'bundi'), 885.9999999999999)
# (('prune', 'thaws', 'block'), 885.98)
# (('poach', 'burns', 'field'), 885.9799999999999)
# (('prime', 'tawny', 'block'), 885.97)
# (('pasty', 'grind', 'block'), 885.96)
# (('drank', 'colby', 'smith'), 885.9200000000001)
# (('paint', 'grove', 'blush'), 885.9100000000001)
# (('spicy', 'baked', 'grown'), 885.8199999999999)
# (('patis', 'clove', 'drunk'), 885.7900000000001)
# (('poach', 'drink', 'melts'), 885.75)
# (('salon', 'brick', 'fudge'), 885.6899999999999)
# ...
# (('cider', 'myoga', 'khubz'), 572.15)
# (('filet', 'apron', 'khubz'), 572.0400000000001)
# (('ghost', 'mixed', 'awful'), 571.9300000000001)
# (('cumin', 'welsh', 'gyoza'), 571.65)
# (('knife', 'dutch', 'gyoza'), 571.49)
# (('cling', 'after', 'jumbo'), 571.47)
# (('dietz', 'scrub', 'myoga'), 571.3)
# (('blitz', 'schwa', 'negro'), 571.0)
# (('zesty', 'divan', 'kombu'), 570.9300000000001)
# (('dream', 'konbu', 'light'), 570.88)
# (('pinto', 'medal', 'khubz'), 570.73)
# (('wilts', 'recao', 'khubz'), 570.72)
# (('quick', 'nestl', 'gyoza'), 570.6700000000001)
# (('quorn', 'schwa', 'devil'), 570.59)
# (('fired', 'myoga', 'khubz'), 570.55)
# (('melts', 'ivory', 'khubz'), 570.5)
# (('grown', 'medal', 'khubz'), 570.5)
# (('sprig', 'melon', 'khubz'), 570.34)
# (('tawny', 'kefir', 'jumbo'), 570.23)
# (('pisco', 'medal', 'khubz'), 570.1800000000001)
# (('packs', 'right', 'elbow'), 570.16)
# (('truck', 'dashi', 'elbow'), 570.08)
# (('yield', 'schwa', 'konbu'), 570.0799999999999)
# (('mouth', 'derby', 'aspic'), 570.02)
# (('liken', 'yacht', 'gumbo'), 570.02)
# (('punch', 'devil', 'myoga'), 569.92)
# (('viand', 'syrup', 'elbow'), 569.88)
# (('truck', 'divan', 'elbow'), 569.76)
# (('drips', 'myoga', 'khubz'), 569.54)
# (('wacky', 'nestl', 'jumbo'), 569.45)
# (('young', 'schwa', 'devil'), 569.41)
# (('brown', 'fudge', 'aspic'), 569.37)
# (('swirl', 'myoga', 'khubz'), 569.05)
# (('crumb', 'nestl', 'gyoza'), 568.8499999999999)
# (('melts', 'apron', 'khubz'), 568.69)
# (('spicy', 'extra', 'jumbo'), 568.45)
# (('field', 'schwa', 'gumbo'), 568.4)
# (('sprig', 'medal', 'khubz'), 568.27)
# (('filet', 'schwa', 'jumbo'), 568.26)
# (('petal', 'micro', 'khubz'), 568.16)
# (('dices', 'myoga', 'khubz'), 567.99)
# (('pinch', 'derby', 'awful'), 567.83)
# (('dutch', 'angel', 'ivory'), 567.68)
# (('moves', 'right', 'awful'), 567.6600000000001)
# (('straw', 'lemon', 'khubz'), 567.59)
# (('pista', 'owner', 'khubz'), 567.5500000000001)
# (('crimp', 'ovens', 'awful'), 567.25)
# (('whips', 'young', 'extra'), 567.1600000000001)
# (('crisp', 'omega', 'khubz'), 566.99)
# (('twine', 'myoga', 'khubz'), 566.82)
# (('pesto', 'magic', 'khubz'), 566.7900000000001)
# (('split', 'recao', 'khubz'), 566.75)
# (('third', 'opens', 'awful'), 566.73)
# (('flips', 'recao', 'khubz'), 566.6700000000001)
# (('ghost', 'derby', 'awful'), 566.63)
# (('flips', 'yacht', 'jumbo'), 566.6)
# (('mould', 'jerky', 'aspic'), 566.5699999999999)
# (('major', 'nestl', 'khubz'), 566.45)
# (('split', 'owner', 'khubz'), 566.23)
# (('wilts', 'acorn', 'khubz'), 566.22)
# (('flips', 'owner', 'khubz'), 566.1500000000001)
# (('squab', 'lemon', 'right'), 566.08)
# (('niter', 'schwa', 'gumbo'), 566.07)
# (('diner', 'schwa', 'jumbo'), 565.9)
# (('straw', 'devil', 'khubz'), 565.84)
# (('Forks', 'thyme', 'awful'), 565.74)
# (('flesh', 'divan', 'gumbo'), 565.6899999999999)
# (('milky', 'dough', 'extra'), 565.6)
# (('milky', 'schwa', 'negro'), 565.55)
# (('rinse', 'myoga', 'khubz'), 565.52)
# (('drunk', 'magic', 'elbow'), 565.1800000000001)
# (('watch', 'kefir', 'gumbo'), 565.04)
# (('jerky', 'dashi', 'gumbo'), 565.01)
# (('jerky', 'divan', 'gumbo'), 564.6899999999999)
# (('Trays', 'devil', 'jumbo'), 564.27)
# (('dietz', 'lunch', 'myoga'), 564.22)
# (('brown', 'thyme', 'aspic'), 564.15)
# (('wilts', 'ocean', 'khubz'), 563.95)
# (('wilts', 'knead', 'jumbo'), 563.64)
# (('scrub', 'devil', 'khoya'), 563.43)
# (('melds', 'tonic', 'khubz'), 563.38)
# (('liner', 'schwa', 'jumbo'), 563.34)
# (('speck', 'ivory', 'awful'), 563.32)
# (('thaws', 'kefir', 'jumbo'), 563.31)
# (('pesto', 'divan', 'khubz'), 563.22)
# (('cedar', 'light', 'kombu'), 563.16)
# (('field', 'yacht', 'jumbo'), 563.15)
# (('whisk', 'young', 'extra'), 562.86)
# (('mouth', 'jerky', 'aspic'), 562.84)
# (('picks', 'after', 'jumbo'), 562.74)
# (('liver', 'schwa', 'gumbo'), 562.55)
# (('ranch', 'devil', 'jumbo'), 562.44)
# (('dietz', 'schwa', 'konbu'), 562.4300000000001)
# (('petal', 'ivory', 'khubz'), 562.41)
# (('grown', 'vital', 'khubz'), 562.2900000000001)
# (('split', 'acorn', 'khubz'), 562.25)
# (('thick', 'syrup', 'elbow'), 562.22)
# (('flips', 'acorn', 'khubz'), 562.1700000000001)
# (('whirl', 'knead', 'gumbo'), 562.16)
# (('knife', 'yacht', 'gumbo'), 561.9)
# (('first', 'angel', 'khubz'), 561.89)
# (('punch', 'devil', 'gyoza'), 561.8599999999999)
# (('world', 'thyme', 'aspic'), 561.76)
# (('ovens', 'lucky', 'right'), 561.59)
# (('scrub', 'knead', 'light'), 561.59)
# (('thick', 'ovens', 'awful'), 561.55)
# (('meson', 'lucky', 'right'), 561.47)
# (('thick', 'meson', 'awful'), 561.4300000000001)
# (('melts', 'avoid', 'khubz'), 561.3000000000001)
# (('jerky', 'witch', 'gumbo'), 561.25)
# (('first', 'ocean', 'khubz'), 561.1800000000001)
# (('pinto', 'derby', 'awful'), 560.92)
# (('first', 'knead', 'jumbo'), 560.87)
# (('whirl', 'zesty', 'jumbo'), 560.73)
# (('pinch', 'jerky', 'awful'), 560.65)
# (('speck', 'light', 'jumbo'), 560.48)
# (('pisco', 'derby', 'awful'), 560.37)
# (('pisco', 'after', 'khubz'), 560.34)
# (('round', 'thyme', 'aspic'), 559.98)
# (('hound', 'jerky', 'aspic'), 559.98)
# (('split', 'ocean', 'khubz'), 559.98)
# (('flips', 'ocean', 'khubz'), 559.9000000000001)
# (('zesty', 'divan', 'gumbo'), 559.88)
# (('jerky', 'vital', 'gumbo'), 559.84)
# (('split', 'knead', 'jumbo'), 559.67)
# (('flips', 'knead', 'jumbo'), 559.59)
# (('speck', 'right', 'jumbo'), 559.46)
# (('ghost', 'jerky', 'awful'), 559.45)
# (('Forks', 'dietz', 'awful'), 559.37)
# (('field', 'acorn', 'khubz'), 558.72)
# (('drunk', 'yacht', 'elbow'), 558.57)
# (('picks', 'thyme', 'awful'), 558.32)
# (('syrup', 'knead', 'light'), 558.08)
# (('wafer', 'light', 'jumbo'), 558.05)
# (('wilts', 'apron', 'khubz'), 557.78)
# (('whips', 'lucky', 'extra'), 557.75)
# (('pilaf', 'ovens', 'khubz'), 557.73)
# (('pilaf', 'meson', 'khubz'), 557.61)
# (('pista', 'lemon', 'khubz'), 557.6)
# (('thick', 'angel', 'jumbo'), 557.52)
# (('first', 'lemon', 'khubz'), 557.48)
# (('pinch', 'after', 'jumbo'), 557.47)
# (('liver', 'yacht', 'jumbo'), 557.3)
# (('opens', 'magic', 'khubz'), 557.25)
# (('punch', 'kefir', 'myoga'), 556.95)
# (('strip', 'angel', 'khubz'), 556.75)
# (('young', 'schwa', 'kefir'), 556.4399999999999)
# (('crumb', 'vodka', 'light'), 556.33)
# (('divan', 'welsh', 'kombu'), 556.1199999999999)
# (('watch', 'devil', 'jumbo'), 556.11)
# (('strip', 'ocean', 'khubz'), 556.0400000000001)
# (('pinch', 'zesty', 'awful'), 555.84)
# (('strip', 'knead', 'jumbo'), 555.73)
# (('tucks', 'devil', 'myoga'), 555.5899999999999)
# (('straw', 'devil', 'jumbo'), 555.51)
# (('blush', 'kefir', 'myoga'), 555.48)
# (('clean', 'right', 'jumbo'), 555.37)
# (('bison', 'jerky', 'awful'), 555.37)
# (('whips', 'after', 'jumbo'), 555.32)
# (('melds', 'konbu', 'right'), 555.08)
# (('plush', 'kefir', 'myoga'), 554.92)
# (('bison', 'lucky', 'extra'), 554.62)
# (('pilaf', 'zesty', 'jumbo'), 554.62)
# (('tiger', 'schwa', 'jumbo'), 554.44)
# (('wipes', 'myoga', 'khubz'), 554.35)
# (('gourd', 'thyme', 'aspic'), 554.1800000000001)
# (('third', 'ovens', 'awful'), 554.14)
# (('stick', 'negro', 'awful'), 554.04)
# (('third', 'meson', 'awful'), 554.02)
# (('kraft', 'devil', 'jumbo'), 553.78)
# (('pinto', 'jerky', 'awful'), 553.74)
# (('liken', 'schwa', 'gumbo'), 553.37)
# (('pisco', 'jerky', 'awful'), 553.19)
# (('drips', 'omega', 'khubz'), 553.14)
# (('bisto', 'jerky', 'awful'), 552.97)
# (('swirl', 'omega', 'khubz'), 552.65)
# (('flesh', 'bundi', 'myoga'), 552.55)
# (('wacky', 'devil', 'jumbo'), 552.41)
# (('strip', 'lemon', 'khubz'), 552.34)
# (('yacht', 'devil', 'konbu'), 552.3)
# (('crumb', 'devil', 'gyoza'), 551.81)
# (('whips', 'knead', 'jumbo'), 551.75)
# (('first', 'angel', 'jumbo'), 551.56)
# (('sprig', 'yacht', 'jumbo'), 551.54)
# (('drunk', 'thyme', 'aspic'), 551.49)
# (('thick', 'nadru', 'elbow'), 551.41)
# (('whisk', 'after', 'jumbo'), 551.02)
# (('filet', 'myoga', 'khubz'), 550.88)
# (('pecan', 'light', 'kombu'), 550.69)
# (('dashi', 'lucky', 'negro'), 550.51)
# (('field', 'apron', 'khubz'), 550.28)
# (('third', 'angel', 'jumbo'), 550.11)
# (('bugle', 'throw', 'aspic'), 549.9200000000001)
# (('picks', 'angel', 'jumbo'), 549.86)
# (('truck', 'nashi', 'elbow'), 549.8)
# (('yield', 'schwa', 'kombu'), 549.73)
# (('pecan', 'right', 'kombu'), 549.6700000000001)
# (('pecan', 'ivory', 'khubz'), 549.44)
# (('major', 'devil', 'khubz'), 549.41)
# (('navel', 'right', 'jumbo'), 548.97)
# (('punch', 'kefir', 'gyoza'), 548.89)
# (('opens', 'vital', 'khubz'), 548.83)
# (('diner', 'myoga', 'khubz'), 548.52)
# (('liken', 'yacht', 'jumbo'), 548.12)
# (('syrup', 'ocean', 'light'), 548.0600000000001)
# (('mixed', 'acorn', 'khubz'), 547.8000000000001)
# (('bison', 'thyme', 'awful'), 547.77)
# (('squid', 'yacht', 'elbow'), 547.58)
# (('tucks', 'devil', 'gyoza'), 547.53)
# (('pisco', 'angel', 'khubz'), 547.46)
# (('blush', 'kefir', 'gyoza'), 547.4200000000001)
# (('flank', 'right', 'jumbo'), 546.94)
# (('ready', 'light', 'jumbo'), 546.91)
# (('plush', 'kefir', 'gyoza'), 546.8599999999999)
# (('witch', 'syrup', 'omega'), 546.69)
# (('field', 'schwa', 'jumbo'), 546.5)
# (('strip', 'angel', 'jumbo'), 546.42)
# (('liner', 'myoga', 'khubz'), 545.96)
# (('flaky', 'right', 'jumbo'), 545.86)
# (('tonic', 'medal', 'khubz'), 545.7)
# (('pisco', 'thyme', 'awful'), 545.59)
# (('knife', 'schwa', 'gumbo'), 545.25)
# (('divan', 'welsh', 'gumbo'), 545.0699999999999)
# (('jerky', 'schwa', 'gumbo'), 545.0)
# (('sprig', 'ocean', 'khubz'), 544.84)
# (('jerky', 'nashi', 'gumbo'), 544.73)
# (('magic', 'ovens', 'khubz'), 544.66)
# (('sprig', 'knead', 'jumbo'), 544.53)
# (('scrub', 'devil', 'myoga'), 544.52)
# (('flesh', 'bundi', 'gyoza'), 544.49)
# (('niter', 'schwa', 'jumbo'), 544.1700000000001)
# (('Trays', 'light', 'jumbo'), 543.99)
# (('flesh', 'divan', 'jumbo'), 543.79)
# (('picks', 'nadru', 'elbow'), 543.75)
# (('sprig', 'thyme', 'awful'), 543.6800000000001)
# (('Foils', 'khubz', 'extra'), 543.58)
# (('watch', 'kefir', 'jumbo'), 543.14)
# (('smoky', 'right', 'awful'), 542.87)
# (('whips', 'angel', 'jumbo'), 542.44)
# (('dietz', 'schwa', 'kombu'), 542.0799999999999)
# (('sprig', 'yacht', 'elbow'), 541.79)
# (('grown', 'devil', 'khubz'), 541.62)
# (('wagon', 'devil', 'khubz'), 541.6)
# (('flips', 'konbu', 'extra'), 541.24)
# (('sprig', 'lemon', 'khubz'), 541.14)
# (('melds', 'acorn', 'khubz'), 541.13)
# (('scrub', 'vodka', 'light'), 540.98)
# (('speck', 'right', 'awful'), 540.9300000000001)
# (('pilaf', 'owner', 'khubz'), 540.71)
# (('liver', 'schwa', 'jumbo'), 540.65)
# (('whirl', 'knead', 'jumbo'), 540.26)
# (('knife', 'yacht', 'jumbo'), 540.0)
# (('leafy', 'right', 'jumbo'), 539.71)
# (('mango', 'devil', 'khubz'), 539.47)
# (('mixed', 'apron', 'khubz'), 539.36)
# (('dirty', 'omega', 'khubz'), 538.7900000000001)
# (('yield', 'schwa', 'gumbo'), 538.68)
# (('whisk', 'angel', 'jumbo'), 538.14)
# (('zesty', 'divan', 'jumbo'), 537.98)
# (('blend', 'throw', 'aspic'), 537.77)
# (('witch', 'angel', 'kombu'), 537.71)
# (('syrup', 'vodka', 'light'), 537.47)
# (('sprig', 'dutch', 'elbow'), 537.46)
# (('medal', 'konbu', 'right'), 537.4)
# (('grown', 'thyme', 'aspic'), 536.94)
# (('wilts', 'myoga', 'khubz'), 536.62)
# (('drunk', 'below', 'aspic'), 536.49)
# (('scrub', 'devil', 'gyoza'), 536.46)
# (('meson', 'vital', 'khubz'), 536.12)
# (('witch', 'knead', 'gumbo'), 535.97)
# (('derby', 'tonic', 'awful'), 535.89)
# (('schwa', 'devil', 'konbu'), 535.6500000000001)
# (('smith', 'negro', 'awful'), 535.64)
# (('melds', 'ivory', 'khubz'), 534.5)
# (('first', 'myoga', 'khubz'), 533.85)
# (('whips', 'konbu', 'extra'), 533.4000000000001)
# (('magic', 'nestl', 'khubz'), 532.98)
# (('melds', 'apron', 'khubz'), 532.69)
# (('split', 'myoga', 'khubz'), 532.65)
# (('flips', 'myoga', 'khubz'), 532.57)
# (('wacky', 'light', 'jumbo'), 532.13)
# (('yacht', 'devil', 'kombu'), 531.95)
# (('welsh', 'bundi', 'myoga'), 531.93)
# (('liken', 'schwa', 'jumbo'), 531.47)
# (('morel', 'khubz', 'aspic'), 531.1800000000001)
# (('wacky', 'right', 'jumbo'), 531.11)
# (('dietz', 'schwa', 'gumbo'), 531.03)
# (('disco', 'after', 'khubz'), 530.4200000000001)
# (('cedar', 'light', 'jumbo'), 530.21)
# (('cling', 'kombu', 'extra'), 529.2)
# (('field', 'myoga', 'khubz'), 529.12)
# (('wilts', 'negro', 'khubz'), 529.0)
# (('yield', 'acorn', 'khubz'), 529.0)
# (('strip', 'myoga', 'khubz'), 528.71)
# (('jerky', 'tonic', 'awful'), 528.71)
# (('magic', 'owner', 'khubz'), 527.64)
# (('tucks', 'divan', 'elbow'), 527.48)
# (('niter', 'myoga', 'khubz'), 526.7900000000001)
# (('pista', 'negro', 'khubz'), 526.35)
# (('dutch', 'kefir', 'myoga'), 525.5799999999999)
# (('split', 'negro', 'khubz'), 525.03)
# (('flips', 'negro', 'khubz'), 524.95)
# (('lunch', 'kefir', 'myoga'), 524.47)
# (('zesty', 'robin', 'awful'), 523.9)
# (('welsh', 'bundi', 'gyoza'), 523.8699999999999)
# (('uncle', 'vodka', 'right'), 523.59)
# (('knife', 'schwa', 'jumbo'), 523.35)
# (('liver', 'myoga', 'khubz'), 523.27)
# (('jerky', 'disco', 'awful'), 523.27)
# (('divan', 'welsh', 'jumbo'), 523.17)
# (('jerky', 'dough', 'aspic'), 522.3299999999999)
# (('thyme', 'robin', 'awful'), 521.11)
# (('yacht', 'devil', 'gumbo'), 520.9)
# (('flips', 'kombu', 'extra'), 520.89)
# (('yield', 'apron', 'khubz'), 520.5600000000001)
# (('wilts', 'omega', 'khubz'), 520.22)
# (('vital', 'owner', 'khubz'), 519.22)
# (('picks', 'other', 'awful'), 518.35)
# (('cajun', 'right', 'elbow'), 518.34)
# (('pecan', 'light', 'jumbo'), 517.74)
# (('disco', 'angel', 'khubz'), 517.54)
# (('dutch', 'kefir', 'gyoza'), 517.52)
# (('first', 'omega', 'khubz'), 517.45)
# (('grove', 'khubz', 'aspic'), 517.3299999999999)
# (('medal', 'ivory', 'khubz'), 516.82)
# (('yield', 'schwa', 'jumbo'), 516.78)
# (('pecan', 'right', 'jumbo'), 516.72)
# (('magic', 'syrup', 'elbow'), 516.47)
# (('lunch', 'kefir', 'gyoza'), 516.4100000000001)
# (('split', 'omega', 'khubz'), 516.25)
# (('flips', 'omega', 'khubz'), 516.1700000000001)
# (('thyme', 'disco', 'awful'), 515.67)
# (('schwa', 'devil', 'kombu'), 515.3)
# (('pinch', 'kombu', 'extra'), 515.2)
# (('witch', 'knead', 'jumbo'), 514.0699999999999)
# (('whips', 'kombu', 'extra'), 513.0500000000001)
# (('divan', 'syrup', 'elbow'), 512.9)
# (('strip', 'omega', 'khubz'), 512.3100000000001)
# (('sumac', 'right', 'elbow'), 511.81)
# (('folds', 'khubz', 'extra'), 510.78)
# (('nestl', 'micro', 'khubz'), 510.72999999999996)
# (('flips', 'gumbo', 'extra'), 509.84)
# (('picks', 'gumbo', 'extra'), 509.42)
# (('dietz', 'schwa', 'jumbo'), 509.13)
# (('sumaq', 'right', 'elbow'), 508.75)
# (('yacht', 'kefir', 'gumbo'), 507.92999999999995)
# (('cling', 'khubz', 'extra'), 506.58)
# (('nestl', 'ivory', 'khubz'), 504.97999999999996)
# (('witch', 'angel', 'jumbo'), 504.76)
# (('thyme', 'quorn', 'aspic'), 504.65)
# (('schwa', 'devil', 'gumbo'), 504.25)
# (('pinch', 'gumbo', 'extra'), 504.15)
# (('thick', 'negro', 'awful'), 503.33000000000004)
# (('thyme', 'flour', 'aspic'), 503.03999999999996)
# (('whips', 'gumbo', 'extra'), 502.0)
# (('zesty', 'micro', 'awful'), 500.77)
# (('micro', 'angel', 'khubz'), 499.84999999999997)
# (('pilaf', 'negro', 'khubz'), 499.50999999999993)
# (('rotel', 'khubz', 'aspic'), 499.33)
# (('yacht', 'devil', 'jumbo'), 499.0)
# (('flips', 'khubz', 'extra'), 498.27)
# (('whisk', 'gumbo', 'extra'), 497.7)
# (('derby', 'koshi', 'awful'), 496.6)
# (('cling', 'extra', 'jumbo'), 496.25)
# (('nestl', 'avoid', 'khubz'), 495.78000000000003)
# (('picks', 'negro', 'awful'), 495.66999999999996)
# (('fudge', 'throw', 'aspic'), 494.94)
# (('acorn', 'devil', 'khubz'), 494.57)
# (('angel', 'ivory', 'khubz'), 494.09999999999997)
# (('schwa', 'kefir', 'gumbo'), 491.28)
# (('flips', 'extra', 'jumbo'), 487.94)
# (('picks', 'extra', 'jumbo'), 487.52)
# (('devil', 'apron', 'khubz'), 486.12999999999994)
# (('yacht', 'kefir', 'jumbo'), 486.03)
# (('pisco', 'khubz', 'extra'), 485.12)
# (('schwa', 'devil', 'jumbo'), 482.35)
# (('pinch', 'extra', 'jumbo'), 482.25)
# (('nestl', 'myoga', 'khubz'), 482.01)
# (('whips', 'extra', 'jumbo'), 480.1)
# (('vital', 'negro', 'khubz'), 478.02)
# (('opens', 'right', 'awful'), 478.0)
# (('whisk', 'extra', 'jumbo'), 475.8)
# (('world', 'khubz', 'aspic'), 473.18)
# (('knead', 'light', 'jumbo'), 471.71)
# (('knead', 'right', 'jumbo'), 470.69)
# (('thyme', 'konbu', 'aspic'), 469.71000000000004)
# (('schwa', 'kefir', 'jumbo'), 469.38)
# (('lodge', 'khubz', 'aspic'), 468.90999999999997)
# (('ovens', 'right', 'awful'), 465.40999999999997)
# (('meson', 'right', 'awful'), 465.2900000000001)
# (('devil', 'myoga', 'khubz'), 464.96999999999997)
# (('disco', 'khubz', 'extra'), 455.2)
# (('grown', 'khubz', 'aspic'), 448.36)
# (('jerky', 'gumbo', 'aspic'), 445.90999999999997)
# (('drunk', 'elbow', 'aspic'), 442.83000000000004)
# (('melon', 'khubz', 'aspic'), 424.54)
# (('owner', 'khubz', 'aspic'), 405.29)
# (('lemon', 'khubz', 'aspic'), 395.34)
# (('negro', 'khubz', 'aspic'), 364.09)
